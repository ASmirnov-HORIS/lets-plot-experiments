# %%
import numpy as np

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="oD6oX5"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("oD6oX5").appendChild(div);
#                     };
#                     var e = document.getElementById("oD6oX5");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
np.random.seed(42)
n = 100
data = {
    'x': np.random.choice(["A", "B", "C"], size=n),
    'y': np.random.normal(size=n),
    'g': np.random.choice(["g1", "g2"], size=n)
}

# %%
def get_plot(params, **additional_params):
    def get_params(params_dict):
        return {**additional_params, **params_dict}

    key = next(key for key in params.keys() if "outlier_" not in key)
    outlier_key = next(key for key in params.keys() if "outlier_" in key)
    value = params[key]
    outlier_value = params[outlier_key]

    p = ggplot(data, aes('x', 'y'))
    return gggrid([
        p + geom_boxplot(**get_params({})) + \
            ggtitle("Default"),
        p + geom_boxplot(**get_params({key: value})) + \
            ggtitle("{0}={1}".format(key, value)),
        p + geom_boxplot(**get_params({outlier_key: outlier_value})) + \
            ggtitle("{0}={1}".format(outlier_key, outlier_value)),
        p + geom_boxplot(**get_params({key: value, outlier_key: outlier_value})) + \
            ggtitle("{0}={1}, {2}={3}".format(key, value, outlier_key, outlier_value)),
    ], ncol=2)

# %%
get_plot({'size': 1.5, 'outlier_size': .4})
# Out:
#    <div id="gmNvII"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"size=1.5"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "size":1.5,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_size=0.4"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_size":0.4,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"size=1.5, outlier_size=0.4"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_size":0.4,
# "size":1.5,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("gmNvII");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
get_plot({'alpha': .5, 'outlier_alpha': .1})
# Out:
#    <div id="MWZSiQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"alpha=0.5"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "alpha":0.5,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_alpha=0.1"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_alpha":0.1,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"alpha=0.5, outlier_alpha=0.1"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "alpha":0.5,
# "outlier_alpha":0.1,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("MWZSiQ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
get_plot({'color': "red", 'outlier_color': "blue"})
# Out:
#    <div id="bJVErS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"color=red"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_color=blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_color":"blue",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"color=red, outlier_color=blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_color":"blue",
# "color":"red",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("bJVErS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
get_plot({'fill': "red", 'outlier_fill': "blue"}, color="black", outlier_shape=21)
# Out:
#    <div id="7syLBr"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":21.0,
# "color":"black",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill=red"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":21.0,
# "color":"black",
# "fill":"red",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_fill=blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_fill":"blue",
# "outlier_shape":21.0,
# "color":"black",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill=red, outlier_fill=blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_fill":"blue",
# "outlier_shape":21.0,
# "color":"black",
# "fill":"red",
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("7syLBr");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
get_plot({'shape': 1, 'outlier_shape': 2})
# Out:
#    <div id="p5kHD3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"shape=1"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "shape":1.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_shape=2"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"shape=1, outlier_shape=2"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":2.0,
# "shape":1.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("p5kHD3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
get_plot({'stroke': 2, 'outlier_stroke': 4}, outlier_shape=1)
# Out:
#    <div id="UqlC5i"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":1.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"stroke=2"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":1.0,
# "stroke":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"outlier_stroke=4"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":1.0,
# "outlier_stroke":4.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"stroke=2, outlier_stroke=4"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_shape":1.0,
# "outlier_stroke":4.0,
# "stroke":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("UqlC5i");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
gggrid([
    ggplot(data, aes('x', 'y')) + geom_boxplot(size=2),
    ggplot(data, aes('x', 'y')) + geom_boxplot(outlier_size=1, size=2),
    ggplot(data, aes('x', 'y')) + geom_boxplot(outlier_size=0, size=2),
])
# Out:
#    <div id="WYVXXi"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "size":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_size":1.0,
# "size":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "outlier_size":0.0,
# "size":2.0,
# "data":{
# "..middle..":[0.17555329395483268,NaN,-0.0073801499445730065,NaN,-0.028463391521671683],
# "..lower..":[-0.513924467938416,NaN,-0.38826439897661413,NaN,-0.5007890008265612],
# "..upper..":[0.6611061177015407,NaN,0.9035324906258424,NaN,0.6547384441356571],
# "..ymin..":[-1.5081532895474827,NaN,-2.022314933195735,NaN,-1.1497925774943585],
# "..ymax..":[1.4039587386592935,NaN,2.5391627162693324,NaN,1.706604953678462],
# "x":["C","A","A","B","B"],
# "y":[NaN,3.372296253626673,NaN,-2.65517604756347,NaN]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("WYVXXi");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
