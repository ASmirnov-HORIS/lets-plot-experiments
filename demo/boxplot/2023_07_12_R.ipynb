# %%
library(ggplot2)

# %%
ggplot(iris, aes(Species, Sepal.Length)) + geom_boxplot()
# Out:
# plot without title

# %%
ggplot(iris, aes(Species, Sepal.Length)) + geom_boxplot(shape = 1)
# Out:
# plot without title

# %%
ggplot(iris, aes(Species, Sepal.Length)) + geom_boxplot(aes(shape = Species)) + scale_shape_manual(values = c(1, 1, 1))
# Out:
# plot without title

# %%
ggplot(iris, aes(Species, Sepal.Length)) + geom_boxplot(outlier.shape = 1)
# Out:
# plot without title
