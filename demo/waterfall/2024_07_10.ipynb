# %% [markdown]
# # Waterfall Chart
#
# See:
#
# - [Wikipedia article](https://en.wikipedia.org/wiki/Waterfall_chart)
# - [ggplot2 + waterfalls](https://r-charts.com/flow/waterfall-chart/)

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="8ERl00"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("8ERl00").appendChild(div);
#                     };
#                     var e = document.getElementById("8ERl00");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data = dict(
    x = ["A", "B", "C", "D", "E"],
    y = [100, 200, -400, 500, -200],
)

# %%
_DY_STAT_NAME = "dy"
_CUMSUM_STAT_NAME = "cumsum"
_INITIAL_STAT_NAME = "initial"
_FLOW_TYPE_STAT_NAME = "Flow type"
_DY_TOOLTIP_TITLE = "Difference"
_CUMSUM_TOOLTIP_TITLE = "Cumulative sum"
_INITIAL_TOOLTIP_TITLE = "Initial"
_FLOW_TYPE_NAMES = {
    "increase": "Increase",
    "decrease": "Decrease",
    "total": "Total",
}
_FLOW_TYPE_BOX_COLORS = {
    "increase": "#4daf4a",
    "decrease": "#e41a1c",
    "total": "#377eb8",
}
_FLOW_TYPE_TEXT_COLORS = {
    "increase": "#b2df8a",
    "decrease": "#fb9a99",
    "total": "#a6cee3",
}
_FLOW_TYPE_COLOR_VALUE = 'flow_type'

_SIZE_DEF = 0
_WIDTH_DEF = .9
_SHOW_LEGEND_DEF = False
_TOOLTIPS_DEF = layer_tooltips().title("^x")\
                                .line("{0}|@{1}".format(_INITIAL_TOOLTIP_TITLE, _INITIAL_STAT_NAME))\
                                .line("{0}|@{1}".format(_DY_TOOLTIP_TITLE, _DY_STAT_NAME))\
                                .line("{0}|@{1}".format(_CUMSUM_TOOLTIP_TITLE, _CUMSUM_STAT_NAME))\
                                .disable_splitting()
_SORTED_VALUE_DEF = False
# Total
_CALC_TOTAL_DEF = True
# Horizontal line
_HLINE_PROPS_DEF = dict(color=None, size=None, linetype='dashed', blank=True)
_HLINE_ONTOP_DEF = True
# Connector lines
_CONNECTOR_PROPS_DEF = dict(color=None, size=None, linetype=None, blank=False)
# Labels
_LABEL_PROPS_DEF = dict(
    color="white",
    family=None, face=None, size=None,
    angle=None,
    hjust=None, vjust=None,
    margin=None,
    blank=False
)

def _get_flow_type_names(total_title):
    flow_type_names = _FLOW_TYPE_NAMES.copy()
    if total_title is not None:
        flow_type_names['total'] = total_title
    return flow_type_names

def _get_props(props, props_def):
    if props is None:
        return props_def
    else:
        return {**props_def, **{k: v for k, v in props.items() if v is not None}}

def _get_stat_data(data, x, y, sorted_value, calc_total, threshold, max_values, flow_type_names):
    xs, ys = data[x], data[y]
    assert len(xs) == len(set(xs)), "x values shouldn't contains duplicates"
    if sorted_value:
        xs, ys = zip(*sorted(zip(xs, ys), key=lambda p: abs(p[1]), reverse=True))
    xs = [str(v) for v in xs]
    if threshold is not None:
        other_value = sum([v for v in ys if abs(v) < threshold])
        xs, ys = zip(*[p for p in zip(xs, ys) if abs(p[1]) >= threshold])
        if abs(other_value) > 0:
            xs = list(xs) + ["Other"]
            ys = list(ys) + [other_value]
    elif max_values is not None:
        indices = list(zip(*sorted(zip(range(len(xs)), xs, ys), key=lambda p: abs(p[2]), reverse=True)))[0][:max_values]
        other_value = sum([v for i, v in enumerate(ys) if i not in indices], 0)
        xs = [v for i, v in enumerate(xs) if i in indices]
        ys = [v for i, v in enumerate(ys) if i in indices]
        if abs(other_value) > 0:
            xs = xs + ["Other"]
            ys = ys + [other_value]
    cum_sum = 0
    yprev = []
    ynext = []
    ymin = []
    ymax = []
    flow_type = []
    for y_val in ys:
        yprev.append(cum_sum)
        ynext.append(cum_sum + y_val)
        ymin.append(min(cum_sum, ynext[-1]))
        ymax.append(max(cum_sum, ynext[-1]))
        flow_type.append(flow_type_names["increase"] if y_val >= 0 else flow_type_names["decrease"])
        cum_sum = ynext[-1]
    if calc_total:
        xs = list(xs) + [flow_type_names["total"]]
        ys = list(ys) + [cum_sum - ys[0]]
        yprev.append(ys[0])
        ynext.append(cum_sum)
        ymin.append(min(cum_sum, 0))
        ymax.append(max(cum_sum, 0))
        flow_type.append(flow_type_names["total"])
    return {
        'x': xs,
        _INITIAL_STAT_NAME: yprev,
        _CUMSUM_STAT_NAME: ynext,
        _DY_STAT_NAME: ys,
        'ymin': ymin,
        'ymax': ymax,
        _FLOW_TYPE_STAT_NAME: flow_type,
    }

def _get_annotations_data(stat_data, calc_total):
    n = len(stat_data['x'])
    return {**stat_data,
            **{'y': [(stat_data["ymin"][i] + stat_data["ymax"][i]) / 2 \
                     for i in range(n)],
               'label': [(stat_data[_DY_STAT_NAME][i] if i < n - 1 or not calc_total else stat_data[_CUMSUM_STAT_NAME][i]) \
                         for i in range(n)]}}

def _get_intermediate_lines(stat_data):
    from itertools import pairwise
    xs = []
    ys = []
    xends = []
    yends = []
    for i in range(len(stat_data['x']) - 1):
        xs.append(stat_data['x'][i])
        ys.append(stat_data[_CUMSUM_STAT_NAME][i])
    return {
        'x': xs,
        'y': ys,
    }

def _append_hline_layer(p, hline):
    hline = _get_props(hline, _HLINE_PROPS_DEF)
    if hline['blank'] != True:
        p += geom_hline(yintercept=0, color=hline['color'], size=hline['size'], linetype=hline['linetype'], tooltips='none')
    return p

def _append_connector_layer(p, connector, stat_data, width):
    connector = _get_props(connector, _CONNECTOR_PROPS_DEF)
    if connector['blank'] != True:
        actual_width = _WIDTH_DEF if width is None else width
        p += geom_spoke(aes('x', 'y'), angle=0, radius=1-actual_width, \
                        data=_get_intermediate_lines(stat_data), \
                        position=position_nudge(x=.5-(1-actual_width)/2.0), \
                        linetype=connector['linetype'], \
                        color=connector['color'], size=connector['size'], tooltips='none')
    return p

def _append_label_layer(p, label, stat_data, calc_total, label_format, show_legend):
    label = _get_props(label, _LABEL_PROPS_DEF)
    if label['blank'] != True:
        label_mapping_dict = {'x': 'x', 'y': 'y', 'label': 'label'}
        color_is_mapped = label['color'] == _FLOW_TYPE_COLOR_VALUE
        if color_is_mapped:
            label_mapping_dict['color'] = _FLOW_TYPE_STAT_NAME
            label['color'] = None
        p += geom_text(aes(**label_mapping_dict), \
                       data=_get_annotations_data(stat_data, calc_total), \
                       color=label['color'], label_format=label_format, \
                       family=label['family'], fontface=label['face'], size=label['size'],
                       angle=label['angle'], hjust=label['hjust'], vjust=label['vjust'],
                       show_legend=(show_legend and color_is_mapped))
    return p

def _append_scales(p, calc_total, flow_type_names):
    actual_flow_type_names = list(flow_type_names.keys())
    if not calc_total:
        actual_flow_type_names.remove('total')
    return p + \
        scale_fill_manual(values={flow_type_names[k]: _FLOW_TYPE_BOX_COLORS[k] for k in actual_flow_type_names}) + \
        scale_color_manual(values={flow_type_names[k]: _FLOW_TYPE_TEXT_COLORS[k] for k in actual_flow_type_names})

def waterfall_plot(data, x, y, *, \
                   color=None, fill=_FLOW_TYPE_COLOR_VALUE, size=_SIZE_DEF, alpha=None, linetype=None, width=_WIDTH_DEF, \
                   show_legend=_SHOW_LEGEND_DEF, tooltips=_TOOLTIPS_DEF, \
                   sorted_value=_SORTED_VALUE_DEF, threshold=None, max_values=None, \
                   calc_total=_CALC_TOTAL_DEF, total_title=None, \
                   hline=None, hline_ontop=_HLINE_ONTOP_DEF, \
                   connector=None, \
                   label=None, label_format=None):
    # Step 1: Prepare dict of flow_type names
    flow_type_names = _get_flow_type_names(total_title)
    # Step 2: Use flow_type_names to prepare the stat data and the mapping
    stat_data = _get_stat_data(data, x, y, sorted_value, calc_total, threshold, max_values, flow_type_names)
    mapping_dict = {'x': 'x', 'y': _CUMSUM_STAT_NAME, 'ymin': 'ymin', 'ymax': 'ymax'}
    if fill == _FLOW_TYPE_COLOR_VALUE:
        mapping_dict['fill'] = _FLOW_TYPE_STAT_NAME
        fill = None
    # Step 3: Build plot from different layers
    p = ggplot()
    if not hline_ontop:
        p = _append_hline_layer(p, hline)
    p = _append_connector_layer(p, connector, stat_data, width)
    p += geom_crossbar(aes(**mapping_dict), \
                       data=stat_data, \
                       fatten=0, \
                       color=color, fill=fill, size=size, alpha=alpha, linetype=linetype, \
                       width=width, \
                       show_legend=show_legend, tooltips=tooltips)
    if hline_ontop:
        p = _append_hline_layer(p, hline)
    p = _append_label_layer(p, label, stat_data, calc_total, label_format, show_legend)
    p = _append_scales(p, calc_total, flow_type_names)
    return p

# %% [markdown]
# ## Default

# %%
waterfall_plot(data, 'x', 'y')
# Out:
#    <div id="54kyk4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("54kyk4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Parameters

# %% [markdown]
# ### Aesthetics

# %%
# color
waterfall_plot(data, 'x', 'y', color="magenta")
# Out:
#    <div id="y3vsTZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "color":"magenta",
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("y3vsTZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# fill
waterfall_plot(data, 'x', 'y', fill="blue")
# Out:
#    <div id="ZRTtKM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "fill":"blue",
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ZRTtKM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# size
waterfall_plot(data, 'x', 'y', size=2)
# Out:
#    <div id="iW6jVD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":2.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("iW6jVD");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# alpha
waterfall_plot(data, 'x', 'y', alpha=.5)
# Out:
#    <div id="EOMTmE"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "alpha":0.5,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("EOMTmE");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# linetype
waterfall_plot(data, 'x', 'y', size=1, linetype='dashed')
# Out:
#    <div id="1unyeY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":1.0,
# "linetype":"dashed",
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("1unyeY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# width
waterfall_plot(data, 'x', 'y', width=.4)
# Out:
#    <div id="cA5CZU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.2
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.6
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.4
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cA5CZU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Standard parameters

# %%
# show_legend
gggrid([
    waterfall_plot(data, 'x', 'y', show_legend=True) + ggtitle("Show legend", "Default calc_total"),
    waterfall_plot(data, 'x', 'y', show_legend=True, calc_total=False) + ggtitle("Show legend", "calc_total=False"),
])
# Out:
#    <div id="BqMTo6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Show legend",
# "subtitle":"Default calc_total"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Show legend",
# "subtitle":"calc_total=False"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease"],
# "values":["#4daf4a","#e41a1c"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease"],
# "values":["#b2df8a","#fb9a99"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D"],
# "y":[100.0,300.0,-100.0,400.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E"],
# "initial":[0.0,100.0,300.0,-100.0,400.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[50.0,200.0,100.0,150.0,300.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("BqMTo6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# tooltips
gggrid([
    waterfall_plot(data, 'x', 'y', tooltips='none'),
    waterfall_plot(data, 'x', 'y', tooltips=layer_tooltips().line("@dy: from @initial to @cumsum").disable_splitting())
])
# Out:
#    <div id="wb3Muu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":"none",
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["@dy: from @initial to @cumsum"],
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("wb3Muu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Waterfall-specific parameters

# %%
# sorted_value
waterfall_plot(data, 'x', 'y', sorted_value=True)
# Out:
#    <div id="GaAaVa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["D","C","B","E","A"],
# "y":[500.0,100.0,300.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["D","C","B","E","A","Total"],
# "initial":[0.0,500.0,100.0,300.0,100.0,500.0],
# "cumsum":[500.0,100.0,300.0,100.0,200.0,200.0],
# "dy":[500.0,-400.0,200.0,-200.0,100.0,-300.0],
# "ymin":[0.0,100.0,100.0,100.0,100.0,0.0],
# "ymax":[500.0,500.0,300.0,300.0,200.0,200.0],
# "Flow type":["Increase","Decrease","Increase","Decrease","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["D","C","B","E","A","Total"],
# "y":[250.0,300.0,200.0,200.0,150.0,100.0],
# "label":[500.0,-400.0,200.0,-200.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GaAaVa");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# threshold
waterfall_plot(data, 'x', 'y', threshold=300)
# Out:
#    <div id="mwrRm5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["C","D","Other"],
# "y":[-400.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["C","D","Other","Total"],
# "initial":[0.0,-400.0,100.0,-400.0],
# "cumsum":[-400.0,100.0,200.0,200.0],
# "dy":[-400.0,500.0,100.0,600.0],
# "ymin":[-400.0,-400.0,100.0,0.0],
# "ymax":[0.0,100.0,200.0,200.0],
# "Flow type":["Decrease","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["C","D","Other","Total"],
# "y":[-200.0,-150.0,150.0,100.0],
# "label":[-400.0,500.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("mwrRm5");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# max_values
waterfall_plot(data, 'x', 'y', max_values=3)
# Out:
#    <div id="ziLuEh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["B","C","D","Other"],
# "y":[200.0,-200.0,300.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["B","C","D","Other","Total"],
# "initial":[0.0,200.0,-200.0,300.0,200.0],
# "cumsum":[200.0,-200.0,300.0,200.0,200.0],
# "dy":[200.0,-400.0,500.0,-100.0,0.0],
# "ymin":[0.0,-200.0,-200.0,200.0,0.0],
# "ymax":[200.0,200.0,300.0,300.0,200.0],
# "Flow type":["Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["B","C","D","Other","Total"],
# "y":[100.0,0.0,50.0,250.0,100.0],
# "label":[200.0,-400.0,500.0,-100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ziLuEh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Use threshold to skip zeros
data_with_zeros = dict(
    x=['a', 'b', 'c', 'd', 'e'],
    y=[1, -2, 3, 0, 1],
)

gggrid([
    waterfall_plot(data_with_zeros, 'x', 'y'),
    waterfall_plot(data_with_zeros, 'x', 'y', threshold=1),
])
# Out:
#    <div id="3TrXpy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["a","b","c","d","e"],
# "y":[1.0,-1.0,2.0,2.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["a","b","c","d","e","Total"],
# "initial":[0.0,1.0,-1.0,2.0,2.0,1.0],
# "cumsum":[1.0,-1.0,2.0,2.0,3.0,3.0],
# "dy":[1.0,-2.0,3.0,0.0,1.0,2.0],
# "ymin":[0.0,-1.0,-1.0,2.0,2.0,0.0],
# "ymax":[1.0,1.0,2.0,2.0,3.0,3.0],
# "Flow type":["Increase","Decrease","Increase","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["a","b","c","d","e","Total"],
# "y":[0.5,0.0,0.5,2.0,2.5,1.5],
# "label":[1.0,-2.0,3.0,0.0,1.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["a","b","c","e"],
# "y":[1.0,-1.0,2.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["a","b","c","e","Total"],
# "initial":[0.0,1.0,-1.0,2.0,1.0],
# "cumsum":[1.0,-1.0,2.0,3.0,3.0],
# "dy":[1.0,-2.0,3.0,1.0,2.0],
# "ymin":[0.0,-1.0,-1.0,2.0,0.0],
# "ymax":[1.0,1.0,2.0,3.0,3.0],
# "Flow type":["Increase","Decrease","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["a","b","c","e","Total"],
# "y":[0.5,0.0,0.5,2.5,1.5],
# "label":[1.0,-2.0,3.0,1.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("3TrXpy");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# calc_total
waterfall_plot(data, 'x', 'y', calc_total=False)
# Out:
#    <div id="DLsep5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease"],
# "values":["#4daf4a","#e41a1c"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease"],
# "values":["#b2df8a","#fb9a99"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D"],
# "y":[100.0,300.0,-100.0,400.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E"],
# "initial":[0.0,100.0,300.0,-100.0,400.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[50.0,200.0,100.0,150.0,300.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DLsep5");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# total_title
waterfall_plot(data, 'x', 'y', total_title="Result", show_legend=True)
# Out:
#    <div id="9cY48S"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Result"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Result"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Result"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Result"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Result"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9cY48S");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Control additional geometries

# %%
# hline
waterfall_plot(data, 'x', 'y', hline=element_line())
# Out:
#    <div id="F52udZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("F52udZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline_ontop
waterfall_plot(data, 'x', 'y', hline=element_line(), hline_ontop=False)
# Out:
#    <div id="nYSkPL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("nYSkPL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline color
waterfall_plot(data, 'x', 'y', hline=element_line(color="magenta"))
# Out:
#    <div id="3C24Ly"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "color":"magenta",
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3C24Ly");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline size
waterfall_plot(data, 'x', 'y', hline=element_line(size=2))
# Out:
#    <div id="5ptY3C"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "size":2.0,
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("5ptY3C");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline linetype
waterfall_plot(data, 'x', 'y', hline=element_line(linetype='solid'))
# Out:
#    <div id="PO7nCc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "linetype":"solid",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("PO7nCc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector
waterfall_plot(data, 'x', 'y', width=.5, connector=element_line(blank=True))
# Out:
#    <div id="YQCxtH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("YQCxtH");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector color
waterfall_plot(data, 'x', 'y', width=.5, connector=element_line(color="magenta"))
# Out:
#    <div id="yecD9D"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.25
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.5,
# "color":"magenta"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("yecD9D");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector size
waterfall_plot(data, 'x', 'y', width=.5, connector=element_line(size=2))
# Out:
#    <div id="aeKjkW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.25
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.5,
# "size":2.0
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("aeKjkW");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector linetype
waterfall_plot(data, 'x', 'y', width=.5, connector=element_line(linetype='dotted'))
# Out:
#    <div id="dHOYNg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.25
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.5,
# "linetype":"dotted"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dHOYNg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label
waterfall_plot(data, 'x', 'y', label=element_text(blank=True))
# Out:
#    <div id="bvPVa2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bvPVa2");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label color
waterfall_plot(data, 'x', 'y', label=element_text(color="yellow"))
# Out:
#    <div id="3PpydR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"yellow"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3PpydR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label family
waterfall_plot(data, 'x', 'y', label=element_text(family="Courier"))
# Out:
#    <div id="7mYfjk"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "family":"Courier"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("7mYfjk");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label face
waterfall_plot(data, 'x', 'y', label=element_text(face='bold'))
# Out:
#    <div id="aqhQWj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "fontface":"bold"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("aqhQWj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label size
waterfall_plot(data, 'x', 'y', label=element_text(size=12))
# Out:
#    <div id="jwjSKX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "size":12.0
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jwjSKX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label angle
waterfall_plot(data, 'x', 'y', label=element_text(angle=45))
# Out:
#    <div id="k3onJL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "angle":45.0
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("k3onJL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label hjust/vjust
def get_waterfall_with_justified_labels(hjust, vjust):
    return waterfall_plot(data, 'x', 'y', label=element_text(hjust=hjust, vjust=vjust)) + \
        ggtitle("Justified labels", "hjust={0}, vjust={1}".format(hjust, vjust))

gggrid([
    get_waterfall_with_justified_labels(0, 0), get_waterfall_with_justified_labels(0, 1),
    get_waterfall_with_justified_labels(1, 0), get_waterfall_with_justified_labels(1, 1),
], ncol=2)
# Out:
#    <div id="ck4akG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Justified labels",
# "subtitle":"hjust=0, vjust=0"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "hjust":0.0,
# "vjust":0.0
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Justified labels",
# "subtitle":"hjust=0, vjust=1"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "hjust":0.0,
# "vjust":1.0
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Justified labels",
# "subtitle":"hjust=1, vjust=0"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "hjust":1.0,
# "vjust":0.0
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Justified labels",
# "subtitle":"hjust=1, vjust=1"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white",
# "hjust":1.0,
# "vjust":1.0
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ck4akG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label_format
waterfall_plot(data, 'x', 'y', label_format=".2f")
# Out:
#    <div id="fUF5rq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "label_format":".2f",
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("fUF5rq");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Other Customizations

# %%
# fill and color

gggrid([
    waterfall_plot(data, 'x', 'y', show_legend=True) + ggtitle("Default"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill='flow_type') + ggtitle("fill='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, label=element_text(color='flow_type')) + ggtitle("label color='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill=None, label=element_text(color='flow_type')) + ggtitle("fill=None and label color='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, color="#777777", label=element_text(color="#777777")) + \
        scale_fill_manual({"Increase": "white", "Decrease": "black", "Total": "yellow"}) + \
        ggtitle("Custom scale_fill_manual()"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill="black", label=element_text(color='flow_type')) + \
        scale_color_manual({"Increase": "green", "Decrease": "red", "Total": "#bbbbbb"}) + \
        ggtitle("Custom scale_color_manual()"),
    waterfall_plot(data, 'x', 'y', show_legend=True, color="#777777", label=element_text(color="#777777")) + \
        scale_fill_manual({"Increase": "green", "Decrease": "red", "Total": "yellow"}, labels=["Up", "Down", "Result"]) + \
        ggtitle("Custom flow type names"),
], ncol=3)
# Out:
#    <div id="MLfjx7"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"label color='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label",
# "color":"Flow type"
# },
# "show_legend":true,
# "data_meta":{
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill=None and label color='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label",
# "color":"Flow type"
# },
# "show_legend":true,
# "data_meta":{
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Custom scale_fill_manual()"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# },{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["white","black","yellow"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "color":"#777777",
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },

# %%
# flip coordinates
waterfall_plot(data, 'x', 'y') + coord_flip()
# Out:
#    <div id="XfXg86"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("XfXg86");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# custom theme
waterfall_plot(data, 'x', 'y') + theme_bw()
# Out:
#    <div id="YPq4rx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "position":{
# "name":"nudge",
# "x":0.45
# },
# "tooltips":"none",
# "data_meta":{
# },
# "angle":0.0,
# "radius":0.09999999999999998
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0,
# "width":0.9
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("YPq4rx");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
