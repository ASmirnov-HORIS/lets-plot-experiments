# %% [markdown]
# # Waterfall Chart
#
# See:
#
# - [Wikipedia article](https://en.wikipedia.org/wiki/Waterfall_chart)
# - [ggplot2 + waterfalls](https://r-charts.com/flow/waterfall-chart/)

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="6c3MrN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("6c3MrN").appendChild(div);
#                     };
#                     var e = document.getElementById("6c3MrN");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data = dict(
    x = ["A", "B", "C", "D", "E"],
    y = [100, 200, -400, 500, -200],
)

# %%
_DY_NAME = "dy"
_CUMSUM_NAME = "cumsum"
_INITIAL_NAME = "initial"
_DY_TITLE = "Difference"
_CUMSUM_TITLE = "Cumulative sum"
_INITIAL_TITLE = "Initial"
_FLOW_TYPE_TITLE = "Flow type"
_FLOW_TYPE_NAMES = {
    "increase": "Increase",
    "decrease": "Decrease",
    "total": "Total",
}
_FLOW_TYPE_BOX_COLORS = {
    "increase": "#4daf4a",
    "decrease": "#e41a1c",
    "total": "#377eb8",
}
_FLOW_TYPE_TEXT_COLORS = {
    "increase": "#b2df8a",
    "decrease": "#fb9a99",
    "total": "#a6cee3",
}
_FLOW_TYPE_COLOR_VALUE = 'flow_type'

_FILL_DEF = "lightgray"
_SHOW_LEGEND_DEF = False
_TOOLTIPS_DEF = layer_tooltips().title("^x")\
                                .line("{0}|@{1}".format(_INITIAL_TITLE, _INITIAL_NAME))\
                                .line("{0}|@{1}".format(_DY_TITLE, _DY_NAME))\
                                .line("{0}|@{1}".format(_CUMSUM_TITLE, _CUMSUM_NAME))\
                                .disable_splitting()
_SORTED_VALUE_DEF = False
# Total
_CALC_TOTAL_DEF = True
# Horizontal line
_HLINE_DEF = False
_HLINE_ONTOP_DEF = True
# Connector lines
_CONNECTOR_LINES_DEF = True
# Labels
_LABELS_DEF = True
_LABEL_COLOR_DEF = "white"

def _get_stat_data(data, x, y, sorted_value, calc_total, threshold, flow_type_names):
    xs, ys = data[x], data[y]
    assert len(xs) == len(set(xs)), "x values shouldn't contains duplicates"
    if sorted_value:
        xs, ys = zip(*sorted(zip(xs, ys), key=lambda p: abs(p[1]), reverse=True))
    xs = [str(v) for v in xs]
    if threshold is not None:
        other_value = sum([v for v in ys if abs(v) < threshold])
        xs, ys = zip(*[p for p in zip(xs, ys) if abs(p[1]) >= threshold])
        if abs(other_value) > 0:
            xs = list(xs) + ["Other"]
            ys = list(ys) + [other_value]
    cum_sum = 0
    yprev = []
    ynext = []
    ymin = []
    ymax = []
    flow_type = []
    for y_val in ys:
        yprev.append(cum_sum)
        ynext.append(cum_sum + y_val)
        ymin.append(min(cum_sum, ynext[-1]))
        ymax.append(max(cum_sum, ynext[-1]))
        flow_type.append(flow_type_names["increase"] if y_val >= 0 else flow_type_names["decrease"])
        cum_sum = ynext[-1]
    if calc_total:
        xs = list(xs) + [flow_type_names["total"]]
        ys = list(ys) + [cum_sum - ys[0]]
        yprev.append(ys[0])
        ynext.append(cum_sum)
        ymin.append(min(cum_sum, 0))
        ymax.append(max(cum_sum, 0))
        flow_type.append(flow_type_names["total"])
    return {
        'x': xs,
        _INITIAL_NAME: yprev,
        _CUMSUM_NAME: ynext,
        _DY_NAME: ys,
        'ymin': ymin,
        'ymax': ymax,
        _FLOW_TYPE_TITLE: flow_type,
    }

def _get_annotations_data(stat_data):
    n = len(stat_data['x'])
    return {**stat_data,
            **{'y': [(stat_data["ymin"][i] + stat_data["ymax"][i]) / 2 \
                     for i in range(n)],
               'label': [(stat_data[_DY_NAME][i] if i < n - 1 else stat_data[_CUMSUM_NAME][i]) \
                         for i in range(n)]}}

def _get_intermediate_lines(stat_data):
    from itertools import pairwise
    xs = []
    ys = []
    xends = []
    yends = []
    for i, j in list(pairwise(range(len(stat_data['x'])))):
        xs.append(stat_data['x'][i])
        ys.append(stat_data[_CUMSUM_NAME][i])
        xends.append(stat_data['x'][j])
        yends.append(stat_data[_CUMSUM_NAME][i])
    return {
        'x': xs,
        'y': ys,
        'xend': xends,
        'yend': yends,
    }

def waterfall_plot(data, x, y, *, \
                   color=None, fill=_FLOW_TYPE_COLOR_VALUE, size=None, alpha=None, linetype=None, width=None, \
                   show_legend=_SHOW_LEGEND_DEF, tooltips=_TOOLTIPS_DEF, \
                   sorted_value=_SORTED_VALUE_DEF, threshold=None, \
                   calc_total=_CALC_TOTAL_DEF, total_title=None, \
                   hline=_HLINE_DEF, hline_ontop=_HLINE_ONTOP_DEF, hline_color=None, hline_size=None, hline_linetype=None, \
                   connector_lines=_CONNECTOR_LINES_DEF, connector_linetype=None, \
                   labels=_LABELS_DEF, label_color=_LABEL_COLOR_DEF):

    flow_type_names = _FLOW_TYPE_NAMES.copy()
    if total_title is not None:
        flow_type_names['total'] = total_title
    stat_data = _get_stat_data(data, x, y, sorted_value, calc_total, threshold, flow_type_names)
    mapping_dict = {'x': 'x', 'y': _CUMSUM_NAME, 'ymin': 'ymin', 'ymax': 'ymax'}
    if fill == _FLOW_TYPE_COLOR_VALUE:
        mapping_dict['fill'] = _FLOW_TYPE_TITLE
        fill = None

    p = ggplot()
    hline_layer = geom_hline(yintercept=0, color=hline_color, size=hline_size, linetype=hline_linetype, tooltips='none')
    if hline and not hline_ontop:
        p += hline_layer
    if connector_lines:
        p += geom_segment(aes('x', 'y', xend='xend', yend='yend'), \
                          data=_get_intermediate_lines(stat_data), \
                          linetype=connector_linetype, \
                          color=color, size=size, tooltips='none')
    p += geom_crossbar(aes(**mapping_dict), \
                       data=stat_data, \
                       fatten=0, \
                       color=color, fill=fill, size=size, alpha=alpha, linetype=linetype, \
                       width=width, \
                       show_legend=show_legend, tooltips=tooltips)
    if hline and hline_ontop:
        p += hline_layer
    if labels:
        labels_mapping_dict = {'x': 'x', 'y': 'y', 'label': 'label'}
        color_is_mapped = label_color == _FLOW_TYPE_COLOR_VALUE
        if color_is_mapped:
            labels_mapping_dict['color'] = _FLOW_TYPE_TITLE
            label_color = None
        p += geom_text(aes(**labels_mapping_dict), \
                       data=_get_annotations_data(stat_data), \
                       color=label_color, show_legend=(show_legend and color_is_mapped))
    actual_flow_type_names = list(flow_type_names.keys())
    if not calc_total:
        actual_flow_type_names.remove('total')
    return p + \
        scale_fill_manual(values={flow_type_names[k]: _FLOW_TYPE_BOX_COLORS[k] for k in actual_flow_type_names}) + \
        scale_color_manual(values={flow_type_names[k]: _FLOW_TYPE_TEXT_COLORS[k] for k in actual_flow_type_names})

# %% [markdown]
# ## Default

# %%
waterfall_plot(data, 'x', 'y')
# Out:
#    <div id="4Am3ou"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4Am3ou");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Parameters

# %% [markdown]
# ### Aesthetics

# %%
# color
waterfall_plot(data, 'x', 'y', color="magenta")
# Out:
#    <div id="xIqYzs"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "color":"magenta"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "color":"magenta"
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("xIqYzs");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# fill
waterfall_plot(data, 'x', 'y', fill="blue")
# Out:
#    <div id="8pIGcy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "fill":"blue"
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("8pIGcy");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# size
waterfall_plot(data, 'x', 'y', size=2)
# Out:
#    <div id="TD5hXL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "size":2.0
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":2.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("TD5hXL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# remove borders
waterfall_plot(data, 'x', 'y', size=0)
# Out:
#    <div id="OyC1Q4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "size":0.0
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("OyC1Q4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# alpha
waterfall_plot(data, 'x', 'y', alpha=.5)
# Out:
#    <div id="udXYj3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "alpha":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("udXYj3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# linetype
waterfall_plot(data, 'x', 'y', linetype='dashed')
# Out:
#    <div id="Z1rBFu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "linetype":"dashed"
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Z1rBFu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# width
waterfall_plot(data, 'x', 'y', width=.4)
# Out:
#    <div id="NQS8rz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.4
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("NQS8rz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Standard parameters

# %%
# show_legend
gggrid([
    waterfall_plot(data, 'x', 'y', show_legend=True) + ggtitle("Show legend", "Default calc_total"),
    waterfall_plot(data, 'x', 'y', show_legend=True, calc_total=False) + ggtitle("Show legend", "calc_total=False"),
])
# Out:
#    <div id="Il2Ege"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Show legend",
# "subtitle":"Default calc_total"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Show legend",
# "subtitle":"calc_total=False"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease"],
# "values":["#4daf4a","#e41a1c"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease"],
# "values":["#b2df8a","#fb9a99"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D"],
# "y":[100.0,300.0,-100.0,400.0],
# "xend":["B","C","D","E"],
# "yend":[100.0,300.0,-100.0,400.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E"],
# "initial":[0.0,100.0,300.0,-100.0,400.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[50.0,200.0,100.0,150.0,300.0],
# "label":[100.0,200.0,-400.0,500.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("Il2Ege");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# tooltips
gggrid([
    waterfall_plot(data, 'x', 'y', tooltips='none'),
    waterfall_plot(data, 'x', 'y', tooltips=layer_tooltips().line("@dy: from @initial to @cumsum").disable_splitting())
])
# Out:
#    <div id="jfBbml"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":"none",
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["@dy: from @initial to @cumsum"],
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("jfBbml");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Waterfall-specific parameters

# %%
# sorted_value
waterfall_plot(data, 'x', 'y', sorted_value=True)
# Out:
#    <div id="bvVyf1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["D","C","B","E","A"],
# "y":[500.0,100.0,300.0,100.0,200.0],
# "xend":["C","B","E","A","Total"],
# "yend":[500.0,100.0,300.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["D","C","B","E","A","Total"],
# "initial":[0.0,500.0,100.0,300.0,100.0,500.0],
# "cumsum":[500.0,100.0,300.0,100.0,200.0,200.0],
# "dy":[500.0,-400.0,200.0,-200.0,100.0,-300.0],
# "ymin":[0.0,100.0,100.0,100.0,100.0,0.0],
# "ymax":[500.0,500.0,300.0,300.0,200.0,200.0],
# "Flow type":["Increase","Decrease","Increase","Decrease","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["D","C","B","E","A","Total"],
# "y":[250.0,300.0,200.0,200.0,150.0,100.0],
# "label":[500.0,-400.0,200.0,-200.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bvVyf1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# threshold
waterfall_plot(data, 'x', 'y', threshold=300)
# Out:
#    <div id="2IYyU8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["C","D","Other"],
# "y":[-400.0,100.0,200.0],
# "xend":["D","Other","Total"],
# "yend":[-400.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["C","D","Other","Total"],
# "initial":[0.0,-400.0,100.0,-400.0],
# "cumsum":[-400.0,100.0,200.0,200.0],
# "dy":[-400.0,500.0,100.0,600.0],
# "ymin":[-400.0,-400.0,100.0,0.0],
# "ymax":[0.0,100.0,200.0,200.0],
# "Flow type":["Decrease","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["C","D","Other","Total"],
# "y":[-200.0,-150.0,150.0,100.0],
# "label":[-400.0,500.0,100.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("2IYyU8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Use threshold to skip zeros
data_with_zeros = dict(
    x=['a', 'b', 'c', 'd', 'e'],
    y=[1, -2, 3, 0, 1],
)

gggrid([
    waterfall_plot(data_with_zeros, 'x', 'y'),
    waterfall_plot(data_with_zeros, 'x', 'y', threshold=1),
])
# Out:
#    <div id="BKufKs"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["a","b","c","d","e"],
# "y":[1.0,-1.0,2.0,2.0,3.0],
# "xend":["b","c","d","e","Total"],
# "yend":[1.0,-1.0,2.0,2.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["a","b","c","d","e","Total"],
# "initial":[0.0,1.0,-1.0,2.0,2.0,1.0],
# "cumsum":[1.0,-1.0,2.0,2.0,3.0,3.0],
# "dy":[1.0,-2.0,3.0,0.0,1.0,2.0],
# "ymin":[0.0,-1.0,-1.0,2.0,2.0,0.0],
# "ymax":[1.0,1.0,2.0,2.0,3.0,3.0],
# "Flow type":["Increase","Decrease","Increase","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["a","b","c","d","e","Total"],
# "y":[0.5,0.0,0.5,2.0,2.5,1.5],
# "label":[1.0,-2.0,3.0,0.0,1.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["a","b","c","e"],
# "y":[1.0,-1.0,2.0,3.0],
# "xend":["b","c","e","Total"],
# "yend":[1.0,-1.0,2.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["a","b","c","e","Total"],
# "initial":[0.0,1.0,-1.0,2.0,1.0],
# "cumsum":[1.0,-1.0,2.0,3.0,3.0],
# "dy":[1.0,-2.0,3.0,1.0,2.0],
# "ymin":[0.0,-1.0,-1.0,2.0,0.0],
# "ymax":[1.0,1.0,2.0,3.0,3.0],
# "Flow type":["Increase","Decrease","Increase","Increase","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["a","b","c","e","Total"],
# "y":[0.5,0.0,0.5,2.5,1.5],
# "label":[1.0,-2.0,3.0,1.0,3.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("BKufKs");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# calc_total
waterfall_plot(data, 'x', 'y', calc_total=False)
# Out:
#    <div id="pdYGrz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease"],
# "values":["#4daf4a","#e41a1c"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease"],
# "values":["#b2df8a","#fb9a99"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D"],
# "y":[100.0,300.0,-100.0,400.0],
# "xend":["B","C","D","E"],
# "yend":[100.0,300.0,-100.0,400.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E"],
# "initial":[0.0,100.0,300.0,-100.0,400.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[50.0,200.0,100.0,150.0,300.0],
# "label":[100.0,200.0,-400.0,500.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("pdYGrz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# total_title
waterfall_plot(data, 'x', 'y', total_title="Result", show_legend=True)
# Out:
#    <div id="tYj9ka"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Result"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Result"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Result"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Result"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Result"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Result"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("tYj9ka");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Control additional geometries

# %%
# hline
waterfall_plot(data, 'x', 'y', hline=True)
# Out:
#    <div id="CpdCI6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("CpdCI6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline_ontop
waterfall_plot(data, 'x', 'y', hline=True, hline_ontop=False)
# Out:
#    <div id="dCU1Ls"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "data":{
# }
# },{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dCU1Ls");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline_color
waterfall_plot(data, 'x', 'y', hline=True, hline_color="magenta")
# Out:
#    <div id="SAlh68"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "color":"magenta",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("SAlh68");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline_size
waterfall_plot(data, 'x', 'y', hline=True, hline_size=2)
# Out:
#    <div id="4ffjvG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "size":2.0,
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4ffjvG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# hline_linetype
waterfall_plot(data, 'x', 'y', hline=True, hline_linetype='dashed')
# Out:
#    <div id="0R41DF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0R41DF");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector_lines
waterfall_plot(data, 'x', 'y', width=.5, connector_lines=False)
# Out:
#    <div id="9IV64o"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9IV64o");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector_linetype
waterfall_plot(data, 'x', 'y', width=.5, connector_linetype='dotted')
# Out:
#    <div id="cGBlcJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "linetype":"dotted"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cGBlcJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# labels
waterfall_plot(data, 'x', 'y', labels=False)
# Out:
#    <div id="xgBZYD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("xgBZYD");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label_color
waterfall_plot(data, 'x', 'y', label_color="yellow")
# Out:
#    <div id="Eiiivv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"yellow"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Eiiivv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Other Customizations

# %%
# fill and color

gggrid([
    waterfall_plot(data, 'x', 'y', show_legend=True) + ggtitle("Default"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill='flow_type') + ggtitle("fill='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, label_color='flow_type') + ggtitle("label_color='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill=None, label_color='flow_type') + ggtitle("fill=None and label_color='flow_type'"),
    waterfall_plot(data, 'x', 'y', show_legend=True, color="#777777", label_color="#777777") + \
        scale_fill_manual({"Increase": "white", "Decrease": "black", "Total": "yellow"}) + \
        ggtitle("Custom scale_fill_manual()"),
    waterfall_plot(data, 'x', 'y', show_legend=True, fill="black", label_color='flow_type') + \
        scale_color_manual({"Increase": "green", "Decrease": "red", "Total": "#bbbbbb"}) + \
        ggtitle("Custom scale_color_manual()"),
    waterfall_plot(data, 'x', 'y', show_legend=True, color="#777777", label_color="#777777") + \
        scale_fill_manual({"Increase": "green", "Decrease": "red", "Total": "yellow"}, labels=["Up", "Down", "Result"]) + \
        ggtitle("Custom flow type names"),
], ncol=3)
# Out:
#    <div id="Wdtw2u"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"label_color='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label",
# "color":"Flow type"
# },
# "show_legend":true,
# "data_meta":{
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"fill=None and label_color='flow_type'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label",
# "color":"Flow type"
# },
# "show_legend":true,
# "data_meta":{
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Custom scale_fill_manual()"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# },{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["white","black","yellow"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "color":"#777777"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "color":"#777777"
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,

# %%
# flip coordinates
waterfall_plot(data, 'x', 'y') + coord_flip()
# Out:
#    <div id="9UGCAI"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9UGCAI");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# custom theme
waterfall_plot(data, 'x', 'y') + theme_bw()
# Out:
#    <div id="YNGuQm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"color",
# "breaks":["Increase","Decrease","Total"],
# "values":["#b2df8a","#fb9a99","#a6cee3"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","B","C","D","E"],
# "y":[100.0,300.0,-100.0,400.0,200.0],
# "xend":["B","C","D","E","Total"],
# "yend":[100.0,300.0,-100.0,400.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "initial":[0.0,100.0,300.0,-100.0,400.0,100.0],
# "cumsum":[100.0,300.0,-100.0,400.0,200.0,200.0],
# "dy":[100.0,200.0,-400.0,500.0,-200.0,100.0],
# "ymin":[0.0,100.0,-100.0,-100.0,200.0,0.0],
# "ymax":[100.0,300.0,300.0,400.0,400.0,200.0],
# "Flow type":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Flow type"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Initial|@initial","Difference|@dy","Cumulative sum|@cumsum"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","B","C","D","E","Total"],
# "y":[50.0,200.0,100.0,150.0,300.0,100.0],
# "label":[100.0,200.0,-400.0,500.0,-200.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"label"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("YNGuQm");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
