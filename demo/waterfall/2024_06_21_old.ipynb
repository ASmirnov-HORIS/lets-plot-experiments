# %% [markdown]
# # Waterfall Chart
#
# See:
#
# - [Wikipedia article](https://en.wikipedia.org/wiki/Waterfall_chart)
# - [ggplot2 + waterfalls](https://r-charts.com/flow/waterfall-chart/)

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="fH521V"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("fH521V").appendChild(div);
#                     };
#                     var e = document.getElementById("fH521V");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
_DY_NAME = "dy"
_CUMSUM_NAME = "cumsum"
_INITIAL_NAME = "initial"
_DY_TITLE = "Difference"
_CUMSUM_TITLE = "Cumulative sum"
_INITIAL_TITLE = "Initial"
_DIFF_TITLE = "Difference"
_CATEGORY_COLORS = {
    "increase": "#4daf4a",
    "decrease": "#e41a1c",
    "total": "#377eb8",
}

_SHOW_LEGEND_DEF = False
_FILL_BY_SIGN_DEF = True
_TOOLTIPS_DEF = layer_tooltips().title("^x")\
                                .line("{0}|@{1}".format(_CUMSUM_TITLE, _CUMSUM_NAME))\
                                .line("{0}|@{1}".format(_DY_TITLE, _DY_NAME))\
                                .line("{0}|@{1}".format(_INITIAL_TITLE, _INITIAL_NAME))\
                                .disable_splitting()
_DIFF_CATEGORIES_DEF = {
    "increase": "Increase",
    "decrease": "Decrease",
    "total": "Total",
}
# Total
_CALC_TOTAL_DEF = True
# Horizontal line
_HLINE_DEF = False
# Connector lines
_CONNECTOR_LINES_DEF = True
# Labels
_LABELS_DEF = True
_LABEL_COLOR_DEF = "white"

def _get_stat_data(data, x, y, calc_total, diff_categories):
    xs, ys = data[x], data[y]
    assert len(xs) == len(set(xs)), "x values shouldn't contains duplicates"
    cum_sum = 0
    yprev = []
    ynext = []
    ymin = []
    ymax = []
    diff_type = []
    for y_val in ys:
        yprev.append(cum_sum)
        ynext.append(cum_sum + y_val)
        ymin.append(min(cum_sum, ynext[-1]))
        ymax.append(max(cum_sum, ynext[-1]))
        diff_type.append(diff_categories["increase"] if y_val >= 0 else diff_categories["decrease"])
        cum_sum = ynext[-1]
    if calc_total:
        xs = list(xs) + [diff_categories["total"]]
        ys = list(ys) + [cum_sum - ys[0]]
        yprev.append(ys[0])
        ynext.append(cum_sum)
        ymin.append(min(cum_sum, 0))
        ymax.append(max(cum_sum, 0))
        diff_type.append(diff_categories["total"])
    return {
        'x': xs,
        _INITIAL_NAME: yprev,
        _CUMSUM_NAME: ynext,
        _DY_NAME: ys,
        'ymin': ymin,
        'ymax': ymax,
        _DIFF_TITLE: diff_type,
    }

def _get_annotations_data(stat_data):
    return {**stat_data,
            **{'y': [(stat_data["ymin"][i] + stat_data["ymax"][i]) / 2 \
                     for i in range(len(stat_data["ymin"]))]}}

def _get_intermediate_lines(stat_data):
    from itertools import pairwise
    xs = []
    ys = []
    xends = []
    yends = []
    for i, j in list(pairwise(range(len(stat_data['x'])))):
        xs.append(stat_data['x'][i])
        ys.append(stat_data[_CUMSUM_NAME][i])
        xends.append(stat_data['x'][j])
        yends.append(stat_data[_CUMSUM_NAME][i])
    return {
        'x': xs,
        'y': ys,
        'xend': xends,
        'yend': yends,
    }

def waterfall_plot(data, x, y, *, \
                   color=None, size=None, alpha=None, linetype=None, \
                   show_legend=_SHOW_LEGEND_DEF, tooltips=_TOOLTIPS_DEF, \
                   rect_width=None, \
                   calc_total=_CALC_TOTAL_DEF, fill_by_sign=_FILL_BY_SIGN_DEF, diff_categories=None, \
                   hline=_HLINE_DEF, hline_color=None, hline_size=None, hline_linetype=None, \
                   connector_lines=_CONNECTOR_LINES_DEF, connector_linetype=None, \
                   labels=_LABELS_DEF, label_color=_LABEL_COLOR_DEF):
    diff_categories = _DIFF_CATEGORIES_DEF if diff_categories is None else {**_DIFF_CATEGORIES_DEF, **diff_categories}
    stat_data = _get_stat_data(data, x, y, calc_total, diff_categories)
    fill_rect = _DIFF_TITLE if fill_by_sign else 'x'
    mapping_dict = {'x': 'x', 'y': _CUMSUM_NAME, 'ymin': 'ymin', 'ymax': 'ymax', 'fill': fill_rect}
    p = ggplot()
    if hline:
        p += geom_hline(yintercept=0, color=hline_color, size=hline_size, linetype=hline_linetype, tooltips='none')
    if connector_lines:
        p += geom_segment(aes('x', 'y', xend='xend', yend='yend'), \
                          data=_get_intermediate_lines(stat_data), \
                          linetype=connector_linetype, \
                          color=color, size=size, tooltips='none')
    p += geom_crossbar(aes(**mapping_dict), \
                       data=stat_data, \
                       fatten=0, \
                       color=color, size=size, alpha=alpha, linetype=linetype, \
                       width=rect_width, \
                       show_legend=show_legend, tooltips=tooltips)
    if fill_by_sign:
        p += scale_fill_manual(values={v: _CATEGORY_COLORS[k] for k, v in diff_categories.items()})
    if labels:
        p += geom_text(aes('x', 'y', label=_DY_NAME), \
                       data=_get_annotations_data(stat_data), \
                       color=label_color)
    return p

# %%
data = {'x': ["A", "C", "B", "D", "E"], 'y': [100, 300, -200, 100, -200]}

# %% [markdown]
# ## Default

# %%
waterfall_plot(data, 'x', 'y')
# Out:
#    <div id="1jCfxR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("1jCfxR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Parameters

# %%
# color
waterfall_plot(data, 'x', 'y', color="magenta")
# Out:
#    <div id="UF5Ov9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "color":"magenta"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "color":"magenta"
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("UF5Ov9");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# size
waterfall_plot(data, 'x', 'y', size=2)
# Out:
#    <div id="O9AbUv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "size":2.0
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "size":2.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("O9AbUv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# alpha
waterfall_plot(data, 'x', 'y', alpha=.5)
# Out:
#    <div id="HR8J0x"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "alpha":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("HR8J0x");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# linetype
waterfall_plot(data, 'x', 'y', linetype='dashed')
# Out:
#    <div id="PASlkF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "linetype":"dashed"
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("PASlkF");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# show_legend
waterfall_plot(data, 'x', 'y', show_legend=True)
# Out:
#    <div id="dC4ydz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dC4ydz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# tooltips
gggrid([
    waterfall_plot(data, 'x', 'y', tooltips='none'),
    waterfall_plot(data, 'x', 'y', tooltips=layer_tooltips().line("@dy: from @initial to @cumsum"))
])
# Out:
#    <div id="bYEKZP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":"none",
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["@dy: from @initial to @cumsum"]
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("bYEKZP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# rect_width
waterfall_plot(data, 'x', 'y', rect_width=.4)
# Out:
#    <div id="PasM5E"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.4
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("PasM5E");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# calc_total
waterfall_plot(data, 'x', 'y', calc_total=False)
# Out:
#    <div id="no8Ozu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D"],
# "y":[100.0,400.0,200.0,300.0],
# "xend":["C","B","D","E"],
# "yend":[100.0,400.0,200.0,300.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E"],
# "initial":[0.0,100.0,400.0,200.0,300.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0],
# "y":[50.0,250.0,300.0,250.0,200.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("no8Ozu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# fill_by_sign
waterfall_plot(data, 'x', 'y', fill_by_sign=False)
# Out:
#    <div id="RD72lo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"x"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("RD72lo");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# diff_categories
waterfall_plot(data, 'x', 'y', diff_categories={"total": "Result"}, show_legend=True)
# Out:
#    <div id="TfVxSX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Result"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Result"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Result"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Result"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":true,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Result"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("TfVxSX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector_lines
waterfall_plot(data, 'x', 'y', rect_width=.5, connector_lines=False)
# Out:
#    <div id="LKgcnc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("LKgcnc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# connector_linetype
waterfall_plot(data, 'x', 'y', rect_width=.5, connector_linetype='dotted')
# Out:
#    <div id="laB1DH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "linetype":"dotted"
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0,
# "width":0.5
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("laB1DH");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# labels
waterfall_plot(data, 'x', 'y', labels=False)
# Out:
#    <div id="4dF7pX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4dF7pX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# label_color
waterfall_plot(data, 'x', 'y', label_color="yellow")
# Out:
#    <div id="JHkUpT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"yellow"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("JHkUpT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Other Customizations

# %%
# custom fill
waterfall_plot(data, 'x', 'y', label_color="#777777") + \
    scale_fill_manual({"Increase": "white", "Decrease": "black", "Total": "yellow"})
# Out:
#    <div id="L9fbx2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["white","black","yellow"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"#777777"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("L9fbx2");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# flip coordinates
waterfall_plot(data, 'x', 'y') + coord_flip()
# Out:
#    <div id="f8n0qb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("f8n0qb");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# custom theme
waterfall_plot(data, 'x', 'y') + theme_bw()
# Out:
#    <div id="cnTPn4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"segment",
# "data":{
# "x":["A","C","B","D","E"],
# "y":[100.0,400.0,200.0,300.0,100.0],
# "xend":["C","B","D","E","Total"],
# "yend":[100.0,400.0,200.0,300.0,100.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "xend":"xend",
# "yend":"yend"
# },
# "tooltips":"none",
# "data_meta":{
# }
# },{
# "geom":"crossbar",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "initial":[0.0,100.0,400.0,200.0,300.0,100.0],
# "cumsum":[100.0,400.0,200.0,300.0,100.0,100.0],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "ymin":[0.0,100.0,200.0,200.0,100.0,0.0],
# "ymax":[100.0,400.0,400.0,300.0,300.0,100.0],
# "Difference":["Increase","Increase","Decrease","Increase","Decrease","Total"]
# },
# "mapping":{
# "x":"x",
# "y":"cumsum",
# "ymin":"ymin",
# "ymax":"ymax",
# "fill":"Difference"
# },
# "show_legend":false,
# "tooltips":{
# "formats":[],
# "lines":["Cumulative sum|@cumsum","Difference|@dy","Initial|@initial"],
# "title":"^x",
# "disable_splitting":true
# },
# "data_meta":{
# },
# "fatten":0.0
# },{
# "geom":"text",
# "data":{
# "x":["A","C","B","D","E","Total"],
# "dy":[100.0,300.0,-200.0,100.0,-200.0,0.0],
# "y":[50.0,250.0,300.0,250.0,200.0,50.0]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"dy"
# },
# "data_meta":{
# },
# "color":"white"
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cnTPn4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
