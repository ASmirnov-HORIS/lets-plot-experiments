# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#         <div id="hbqczf"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
#                     window.letsPlotCallQueue = [];
#                     var div = document.createElement("div");
#                     div.style.color = 'darkred';
#                     div.textContent = 'Error loading Lets-Plot JS';
#                     document.getElementById("hbqczf").appendChild(div);
#                 };
#                 var e = document.getElementById("hbqczf");
#                 e.appendChild(script);
#             })()
#         </script>

# %%
def get_plot(hjust=0.5, vjust=0.5):
    return ggplot() + \
        geom_point(x=0, y=0, size=30, shape=12) + \
        geom_text(x=0, y=0, label="TEXT", size=30, color="red", hjust=hjust, vjust=vjust) + \
        ggtitle(f"hjust={hjust}, vjust={vjust}") + \
        theme_gray()

# %%
gggrid([
    get_plot(hjust=0, vjust=0),
    get_plot(hjust=0, vjust=0.5),
    get_plot(hjust=0, vjust=1),
    get_plot(hjust=0.5, vjust=0),
    get_plot(hjust=0.5, vjust=0.5),
    get_plot(hjust=0.5, vjust=1),
    get_plot(hjust=1, vjust=0),
    get_plot(hjust=1, vjust=0.5),
    get_plot(hjust=1, vjust=1),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="7icoUq" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("7icoUq");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0, vjust=0"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.0,
# "vjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.0,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0, vjust=1"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.0,
# "vjust":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=1"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1, vjust=0"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.0,
# "vjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.0,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1, vjust=1"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.0,
# "vjust":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-b747d8309d0c44428d6325f06cffef66', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-b747d8309d0c44428d6325f06cffef66" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %%
gggrid([
    get_plot(hjust=0.25, vjust=0.25),
    get_plot(hjust=0.25, vjust=0.5),
    get_plot(hjust=0.25, vjust=0.75),
    get_plot(hjust=0.5, vjust=0.25),
    get_plot(hjust=0.5, vjust=0.5),
    get_plot(hjust=0.5, vjust=0.75),
    get_plot(hjust=0.75, vjust=0.25),
    get_plot(hjust=0.75, vjust=0.5),
    get_plot(hjust=0.75, vjust=0.75),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="c5Ft2P" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("c5Ft2P");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.25, vjust=0.25"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.25,
# "vjust":0.25,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.25, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.25,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.25, vjust=0.75"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.25,
# "vjust":0.75,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.25"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.25,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.75"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.75,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.75, vjust=0.25"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.75,
# "vjust":0.25,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.75, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.75,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.75, vjust=0.75"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.75,
# "vjust":0.75,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-8c250080e6ab4d5b9415722e2779149f', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-8c250080e6ab4d5b9415722e2779149f" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %%
gggrid([
    get_plot(hjust=-0.5, vjust=-0.5),
    get_plot(hjust=-0.5, vjust=0.5),
    get_plot(hjust=-0.5, vjust=1.5),
    get_plot(hjust=0.5, vjust=-0.5),
    get_plot(hjust=0.5, vjust=0.5),
    get_plot(hjust=0.5, vjust=1.5),
    get_plot(hjust=1.5, vjust=-0.5),
    get_plot(hjust=1.5, vjust=0.5),
    get_plot(hjust=1.5, vjust=1.5),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="DC2GA8" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("DC2GA8");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=-0.5, vjust=-0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":-0.5,
# "vjust":-0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"19"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=-0.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":-0.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"20"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=-0.5, vjust=1.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":-0.5,
# "vjust":1.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"21"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=-0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":-0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"22"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"23"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=1.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":1.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"24"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1.5, vjust=-0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.5,
# "vjust":-0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"25"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"26"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=1.5, vjust=1.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":1.5,
# "vjust":1.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"27"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-e9a978a2275a4f6da28273e2789e6f16', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-e9a978a2275a4f6da28273e2789e6f16" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %%
gggrid([
    get_plot(hjust="left", vjust="bottom"),
    get_plot(hjust="left", vjust="center"),
    get_plot(hjust="left", vjust="top"),
    get_plot(hjust="middle", vjust="bottom"),
    get_plot(hjust="middle", vjust="center"),
    get_plot(hjust="middle", vjust="top"),
    get_plot(hjust="right", vjust="bottom"),
    get_plot(hjust="right", vjust="center"),
    get_plot(hjust="right", vjust="top"),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="zCPH05" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("zCPH05");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=left, vjust=bottom"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"left",
# "vjust":"bottom",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"28"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=left, vjust=center"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"left",
# "vjust":"center",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"29"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=left, vjust=top"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"left",
# "vjust":"top",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"30"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=middle, vjust=bottom"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"middle",
# "vjust":"bottom",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"31"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=middle, vjust=center"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"middle",
# "vjust":"center",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"32"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=middle, vjust=top"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"middle",
# "vjust":"top",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"33"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=right, vjust=bottom"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"right",
# "vjust":"bottom",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"34"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=right, vjust=center"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"right",
# "vjust":"center",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"35"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=right, vjust=top"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"right",
# "vjust":"top",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"36"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-c6f27221dcf949318546713a8e706c79', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-c6f27221dcf949318546713a8e706c79" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %%
gggrid([
    get_plot() + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="inward") + xlim(0, 2) + ylim(0, 2),
    get_plot(vjust="inward") + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="inward", vjust="inward") + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="outward") + xlim(0, 2) + ylim(0, 2),
    get_plot(vjust="outward") + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="outward", vjust="outward") + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="inward", vjust="outward") + xlim(0, 2) + ylim(0, 2),
    get_plot(hjust="outward", vjust="inward") + xlim(0, 2) + ylim(0, 2),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="15Icaq" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("15Icaq");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"37"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=inward, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"inward",
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"38"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=inward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":"inward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"39"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=inward, vjust=inward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"inward",
# "vjust":"inward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"40"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=outward, vjust=0.5"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"outward",
# "vjust":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"41"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=0.5, vjust=outward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":0.5,
# "vjust":"outward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"42"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=outward, vjust=outward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"outward",
# "vjust":"outward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"43"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=inward, vjust=outward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"inward",
# "vjust":"outward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"44"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"hjust=outward, vjust=inward"
# },
# "theme":{
# "name":"gray"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.0,2.0]
# },{
# "aesthetic":"y",
# "limits":[0.0,2.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":30.0,
# "shape":12.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "label":"TEXT",
# "size":30.0,
# "color":"red",
# "hjust":"outward",
# "vjust":"inward",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"45"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-8e43033c283c464288e31c359172b934', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-8e43033c283c464288e31c359172b934" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base
