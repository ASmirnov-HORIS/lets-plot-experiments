# %% [markdown]
# # BBC Visual and Data Journalism Cookbook for Lets-Plot
#
# The notebook is based on [this page](https://bbc.github.io/rcookbook/index.html).
#
# Data is extracted from the [gapminder](https://cran.r-project.org/web/packages/gapminder/README.html) R package.

# %%
import pandas as pd

from lets_plot import *
from lets_plot.mapping import as_discrete

# %%
LetsPlot.setup_html()
# Out:
#             <div id="PT7r91"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("PT7r91").appendChild(div);
#                     };
#                     var e = document.getElementById("PT7r91");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/gapminder.csv")
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
line_size = 1.4

def bbc_theme(x_line='geom', axis_x_margin=[10, 20]):
    def get_element_text(title=False, subtitle=False, size=21):
        face = None
        margin = None
        if title:
            size = 33
            face = "bold"
            margin = [11, 0, 0, 0]
        if subtitle:
            size = 26
            margin = [9, 0, 0, 0]
        return element_text(family="Helvetica", face=face, size=size, margin=margin)
    result = theme(
        plot_title=get_element_text(title=True),
        plot_subtitle=get_element_text(subtitle=True),
        legend_position='top',
        legend_background='blank',
        legend_title='blank',
        legend_text=get_element_text(),
        axis_title='blank',
        axis_text=get_element_text(),
        axis_text_x=element_text(margin=axis_x_margin),
        axis_text_y=element_text(margin=[10, 5]),
        axis_ticks='blank',
        axis_line=element_line(size=2*line_size) if x_line == 'theme' else 'blank',
        axis_ontop_x=x_line == 'theme',
        panel_grid_minor='blank',
        panel_grid_major_x='blank',
        panel_grid_major_y=element_line(size=line_size*6/5, color='#CBCBCB'),
        panel_background='blank',
        strip_text=element_text(size=26, hjust=0),
    )
    if x_line == 'geom':
        result += geom_hline(yintercept=0, size=line_size, color='pen', tooltips='none')
    return result

# %% [markdown]
# ## Make a line chart

# %%
line_df = df[df.country == "Malawi"]

ggplot(line_df, aes('year', 'lifeExp')) + \
    geom_line(color='#1380A1', size=line_size, \
              tooltips=layer_tooltips().format("@year", "d")) + \
    scale_x_continuous(format='d') + \
    bbc_theme() + \
    ggsize(600, 450) + \
    labs(title="Living longer", subtitle="Life expectancy in Malawi 1952-2007")
# Out:
#    <div id="0Urzit"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[36.256,37.207,38.41,39.487,41.766,43.767,45.642,47.457,49.42,47.495,45.009,48.303]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":false,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in Malawi 1952-2007"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "color":"#1380A1",
# "size":1.4,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "size":1.4,
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0Urzit");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
line_df = df[df.country == "China"]

ggplot(line_df, aes('year', 'lifeExp')) + \
    geom_line(color='#1380A1', size=line_size, \
              tooltips=layer_tooltips().format("@year", "d")) + \
    scale_x_continuous(format='d') + \
    bbc_theme() + \
    ggsize(600, 450) + \
    labs(title="Living longer", subtitle="Life expectancy in China 1952-2007")
# Out:
#    <div id="iGFav4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":false,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China 1952-2007"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "color":"#1380A1",
# "size":1.4,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "yintercept":0.0,
# "size":1.4,
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("iGFav4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a multiple line chart

# %%
multiple_line_df = df[df.country.isin(["China", "United States"])]

multiple_line_plot = ggplot(multiple_line_df, aes('year', 'lifeExp', color='country')) + \
    geom_line(size=1, tooltips=layer_tooltips().format("@year", "d")) + \
    scale_x_continuous(format='d') + \
    scale_y_continuous(breaks=list(range(0, 81, 20)), limits=[0, None], expand=[0, 0]) + \
    scale_color_manual(values=['#FAAB18', '#1380A1']) + \
    bbc_theme(x_line='theme') + \
    ggsize(600, 450) + \
    labs(title="Living longer", subtitle="Life expectancy in China and the US")
multiple_line_plot
# Out:
#    <div id="jc2Cpw"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jc2Cpw");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Add color scheme (flavor)

# %%
multiple_line_plot + \
    theme(plot_margin=[20, 30]) + flavor_high_contrast_dark() + \
    ggsize(700, 500)
# Out:
#    <div id="sqHuj9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# },
# "plot_margin":[20.0,30.0],
# "flavor":"high_contrast_dark"
# },
# "ggsize":{
# "width":700.0,
# "height":500.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("sqHuj9");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a bar chart

# %%
bar_df = df[(df.year == 2007)&(df.continent == "Africa")]\
           .sort_values(by=['lifeExp'], ascending=False).head(5)

bars_plot = ggplot(bar_df, aes(as_discrete('country', order=1), 'lifeExp')) + \
    geom_bar(stat='identity', position='identity', fill='#1380A1') + \
    bbc_theme(x_line='theme') + \
    ggsize(640, 480) + \
    labs(title="Reunion is highest", subtitle="Highest African life expectancy, 2007")
bars_plot
# Out:
#    <div id="MnnmdM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("MnnmdM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a stacked bar chart

# %%
stacked_df = df[df.year == 2007].assign(
    lifeExpGrouped=lambda df: pd.cut(
        df.lifeExp, bins=pd.IntervalIndex.from_tuples([(0, 50), (50, 65), (65, 80), (80, 90)])
    ).cat.rename_categories(["Under 50", "50-65", "65-80", "80+"])
).rename(
    columns={'pop': 'continentPop'}
).groupby(['continent', 'lifeExpGrouped'], observed=False).continentPop.sum().reset_index().query('continentPop > 0').assign(
    continentPopPercentage=lambda df: 100 * df.groupby('continent', group_keys=True).continentPop.apply(
        lambda x: x / float(x.sum())
    ).values
)

ggplot(stacked_df, aes('continent', 'continentPopPercentage', fill='lifeExpGrouped')) + \
    geom_bar(stat='identity', size=0, \
             tooltips=layer_tooltips().line('@continentPop').format('@continentPop', ',d')) + \
    scale_y_continuous(breaks=list(range(0, 101, 25)), format='{d}%') + \
    scale_fill_viridis() + \
    bbc_theme(x_line='theme') + \
    theme(legend_justification=[0, 0.05], legend_position=[0, 1], legend_direction='horizontal', \
          plot_subtitle=element_text(margin=[9, 0, 40, 0])) + \
    ggsize(600, 450) + \
    labs(title="How life expectancy varies", subtitle="% of population by life expectancy band, 2007")
# Out:
#    <div id="IGDeLX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "continent":["Africa","Africa","Africa","Americas","Americas","Americas","Asia","Asia","Asia","Asia","Europe","Europe","Oceania"],
# "lifeExpGrouped":["Under 50","50-65","65-80","50-65","65-80","80+","Under 50","50-65","65-80","80+","65-80","80+","80+"],
# "continentPop":[3.76100713E8,3.86811458E8,1.66627521E8,8502814.0,8.56978229E8,3.3390141E7,3.1889923E7,1.401351679E9,2.237837162E9,1.40875063E8,4.04903083E8,1.81195446E8,2.4549947E7],
# "continentPopPercentage":[40.46096323125059,41.613226560313464,17.92581020843594,0.9459435513509575,95.33938168831097,3.714674760338073,0.8365768434581828,36.76203182405441,58.70577828486378,3.695613047623622,69.08447350837832,30.915526491621687,100.0]
# },
# "mapping":{
# "x":"continent",
# "y":"continentPopPercentage",
# "fill":"lifeExpGrouped"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"lifeExpGrouped",
# "factor_levels":["Under 50","50-65","65-80","80+"]
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":[0.0,1.0],
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,40.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# },
# "legend_justification":[0.0,0.05],
# "legend_direction":"horizontal"
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"How life expectancy varies",
# "subtitle":"% of population by life expectancy band, 2007"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "breaks":[0.0,25.0,50.0,75.0,100.0],
# "format":"{d}%"
# },{
# "aesthetic":"fill",
# "scale_mapper_kind":"color_cmap"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@continentPop",
# "format":",d"
# }],
# "lines":["@continentPop"]
# },
# "data_meta":{
# "series_annotations":[{
# "column":"lifeExpGrouped",
# "factor_levels":["Under 50","50-65","65-80","80+"]
# }]
# },
# "size":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("IGDeLX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a grouped bar chart

# %%
grouped_bar_df = pd.melt(
    df[df.year.isin([1967, 2007])][['country', 'year', 'lifeExp']].pivot(
        index='country', columns='year', values='lifeExp'
    ).assign(
        gap=lambda df: df[2007] - df[1967]
    ).sort_values(
        by='gap', ascending=False
    ).head(5).reset_index(),
    id_vars=['country', 'gap'],
    value_vars=[1967, 2007],
    value_name='lifeExp'
)

ggplot(grouped_bar_df, aes(as_discrete('country', order=1), 'lifeExp', \
                           group='year', fill=as_discrete('year'))) + \
    geom_bar(stat='identity', position='dodge') + \
    bbc_theme(x_line='theme') + \
    scale_fill_manual(values=['#1380A1', '#FAAB18']) + \
    ggsize(720, 480) + \
    labs(title="We're living longer", subtitle="Biggest life expectancy rise, 1967-2007")
# Out:
#    <div id="4pArqg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Oman","Vietnam","Yemen, Rep.","Indonesia","Libya","Oman","Vietnam","Yemen, Rep.","Indonesia","Libya"],
# "year":[1967.0,1967.0,1967.0,1967.0,1967.0,2007.0,2007.0,2007.0,2007.0,2007.0],
# "lifeExp":[46.988,47.838,36.984,45.964,50.227,75.64,74.249,62.698,70.65,73.952]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp",
# "group":"year",
# "fill":"year"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# },{
# "aes":"fill",
# "annotation":"as_discrete",
# "parameters":{
# "label":"year"
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":720.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"We're living longer",
# "subtitle":"Biggest life expectancy rise, 1967-2007"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["#1380A1","#FAAB18"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4pArqg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a dumbbell chart

# %%
dumbbell_df = df[df.year.isin([1967, 2007])][['country', 'year', 'lifeExp']].pivot(
    index='country', columns='year', values='lifeExp'
).assign(
    gap=lambda df: df[2007] - df[1967]
).sort_values(
    by='gap'
).tail(10).reset_index()
dumbbell_df.columns = dumbbell_df.columns.map(str)

ggplot(dumbbell_df) + \
    geom_segment(aes(x='1967', xend='2007', y='country', yend='country'), \
                 color='#DDDDDD', size=3) + \
    geom_point(aes(x='1967', y='country'), color='#FAAB18', size=5) + \
    geom_point(aes(x='2007', y='country'), color='#1380A1', size=5) + \
    bbc_theme(x_line='blank', axis_x_margin=[3, 0]) + \
    ggsize(640, 400) + \
    labs(title="We're living longer", subtitle="Biggest life expectancy rise, 1967-2007")
# Out:
#    <div id="Qs7sfQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Tunisia","Egypt","Nepal","Saudi Arabia","Gambia","Libya","Indonesia","Yemen, Rep.","Vietnam","Oman"],
# "1967":[52.053,49.293,41.472,49.901,35.857,50.227,45.964,36.984,47.838,46.988],
# "2007":[73.923,71.338,63.785,72.777,59.448,73.952,70.65,62.698,74.249,75.64]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":false,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[3.0,0.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":400.0
# },
# "ggtitle":{
# "text":"We're living longer",
# "subtitle":"Biggest life expectancy rise, 1967-2007"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"segment",
# "mapping":{
# "x":"1967",
# "y":"country",
# "xend":"2007",
# "yend":"country"
# },
# "data_meta":{
# },
# "color":"#DDDDDD",
# "size":3.0,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"1967",
# "y":"country"
# },
# "data_meta":{
# },
# "color":"#FAAB18",
# "size":5.0,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"2007",
# "y":"country"
# },
# "data_meta":{
# },
# "color":"#1380A1",
# "size":5.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Qs7sfQ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make a histogram

# %%
hist_df = df[df.year == 2007]

breaks = list(range(40, 91, 10))
labels = ['{0} years'.format(y) if y == 90 else str(y) for y in breaks]
ggplot(hist_df, aes('lifeExp')) + \
    geom_histogram(binwidth=5, color='white', fill='#1380A1') + \
    scale_x_continuous(limits=[35, 95], breaks=breaks, labels=labels) + \
    bbc_theme(x_line='theme') + \
    ggsize(600, 450) + \
    labs(title = "How life expectancy varies", subtitle="Distribution of life expectancy in 2007")
# Out:
#    <div id="Ic6X51"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"lifeExp"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"How life expectancy varies",
# "subtitle":"Distribution of life expectancy in 2007"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "breaks":[40.0,50.0,60.0,70.0,80.0,90.0],
# "labels":["40","50","60","70","80","90 years"],
# "limits":[35.0,95.0]
# }],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# },
# "data_meta":{
# },
# "binwidth":5.0,
# "color":"white",
# "fill":"#1380A1",
# "data":{
# "..count..":[0.0,1.0,12.0,9.0,11.0,12.0,11.0,11.0,42.0,29.0,4.0,0.0,0.0,0.0],
# "lifeExp":[34.0,39.0,44.0,49.0,54.0,59.0,64.0,69.0,74.0,79.0,84.0,89.0,94.0,99.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Ic6X51");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make changes to the legend

# %% [markdown]
# ### Remove the legend

# %%
multiple_line_plot + scale_color_manual(values=['#FAAB18', '#1380A1'], guide='none')
# Out:
#    <div id="a90giG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# },{
# "aesthetic":"color",
# "guide":"none",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("a90giG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
multiple_line_plot + theme(legend_position='none')
# Out:
#    <div id="igaaKN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"none",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("igaaKN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Change the position of the legend

# %%
multiple_line_plot + theme(legend_position='right')
# Out:
#    <div id="qnJYF0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"right",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("qnJYF0");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Make changes to the axes

# %% [markdown]
# ### Flip the coordinates of a plot

# %%
bars_plot = bars_plot + coord_flip()
bars_plot
# Out:
#    <div id="aSYrWd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("aSYrWd");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Change the plot limits

# %%
bars_plot + ylim(0, 500)
# Out:
#    <div id="oCp7DH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0.0,500.0]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("oCp7DH");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Change the axis text manually

# %%
breaks = list(range(0, 81, 20))
labels = ['{0} years'.format(y) if y == 80 else str(y) for y in breaks]
bars_plot = bars_plot + \
    scale_y_continuous(limits=[0, 85], breaks=breaks, labels=labels)
bars_plot
# Out:
#    <div id="vYrcOb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "labels":["0","20","40","60","80 years"],
# "limits":[0.0,85.0]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("vYrcOb");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Add axis ticks

# %%
multiple_line_plot + theme(axis_ticks_x=element_line(color='#333333'), axis_ticks_length_x=10)
# Out:
#    <div id="6xv2gA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# },
# "axis_ticks_x":{
# "color":"#333333",
# "blank":false
# },
# "axis_ticks_length_x":10.0
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("6xv2gA");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Add annotations

# %% [markdown]
# ### Add an annotation

# %%
multiple_line_plot + \
    geom_text(x=1980, y=45, label="I'm an annotation!", \
              hjust=0, vjust=0.5, color='#555555', fill='white', \
              family="Helvetica", size=10, tooltips='none')
# Out:
#    <div id="qtElA6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "x":1980.0,
# "y":45.0,
# "label":"I'm an annotation!",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#555555",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("qtElA6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
multiple_line_plot = multiple_line_plot + \
    geom_label(x=1980, y=45, label="I'm quite a long\nannotation over\nthree rows", \
               hjust=0, vjust=0.5, color='#555555', fill='white', \
               family="Helvetica", size=10, label_size=0, tooltips='none') + \
    theme(legend_position='none') + \
    xlim(1950, 2011) + \
    geom_label(x=2007, y=79, label="US", \
               hjust=0, vjust=0.5, color='#1380A1', fill='white', \
               family="Helvetica", size=10, label_size=0, tooltips='none') + \
    geom_label(x=2007, y=72, label="China", \
               hjust=0, vjust=0.5, color='#FAAB18', fill='white', \
               family="Helvetica", size=10, label_size=0, tooltips='none')
multiple_line_plot
# Out:
#    <div id="doKjUR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"none",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# },{
# "aesthetic":"x",
# "limits":[1950.0,2011.0]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":1980.0,
# "y":45.0,
# "label":"I'm quite a long\nannotation over\nthree rows",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#555555",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":2007.0,
# "y":79.0,
# "label":"US",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#1380A1",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":2007.0,
# "y":72.0,
# "label":"China",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#FAAB18",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("doKjUR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Add labels based on your data

# %%
bars_plot + \
    geom_text(aes('country', 'lifeExp', label='lifeExp'), \
              label_format='d', hjust=1, nudge_y=-1.5, color='white', \
              family="Helvetica", size=10)
# Out:
#    <div id="Uvls8a"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "labels":["0","20","40","60","80 years"],
# "limits":[0.0,85.0]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"country",
# "y":"lifeExp",
# "label":"lifeExp"
# },
# "data_meta":{
# },
# "label_format":"d",
# "nudge_y":-1.5,
# "hjust":1.0,
# "color":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Uvls8a");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Add left-aligned labels to bar charts

# %%
bars_plot + \
    geom_text(aes(x='country', label='lifeExp'), y=4, \
              label_format='d', hjust=0, color='white', \
              family="Helvetica", size=10)
# Out:
#    <div id="dWU5sm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["Reunion","Libya","Tunisia","Mauritius","Algeria"],
# "lifeExp":[76.442,73.952,73.923,72.801,72.301]
# },
# "mapping":{
# "x":"country",
# "y":"lifeExp"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"country",
# "order":1.0
# }
# }]
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"top",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":640.0,
# "height":480.0
# },
# "ggtitle":{
# "text":"Reunion is highest",
# "subtitle":"Highest African life expectancy, 2007"
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "labels":["0","20","40","60","80 years"],
# "limits":[0.0,85.0]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "position":"identity",
# "data_meta":{
# },
# "fill":"#1380A1",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"country",
# "label":"lifeExp"
# },
# "data_meta":{
# },
# "label_format":"d",
# "y":4.0,
# "hjust":0.0,
# "color":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dWU5sm");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Add a line

# %%
multiple_line_plot + \
    geom_segment(x=1979, y=45, xend=1965, yend=43, color='#555555', size=line_size*3/4, tooltips='none')
# Out:
#    <div id="c99WIS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "country":["China","China","China","China","China","China","China","China","China","China","China","China","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States"],
# "year":[1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0,1952.0,1957.0,1962.0,1967.0,1972.0,1977.0,1982.0,1987.0,1992.0,1997.0,2002.0,2007.0],
# "lifeExp":[44.0,50.54896,44.50136,58.38112,63.11888,63.96736,65.525,67.274,68.69,70.426,72.028,72.961,68.44,69.49,70.21,70.76,71.34,73.38,74.65,75.02,76.09,76.81,77.31,78.242]
# },
# "mapping":{
# "x":"year",
# "y":"lifeExp",
# "color":"country"
# },
# "data_meta":{
# },
# "theme":{
# "axis_ontop_x":true,
# "axis_title":"blank",
# "axis_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "axis_text_x":{
# "margin":[10.0,20.0],
# "blank":false
# },
# "axis_text_y":{
# "margin":[10.0,5.0],
# "blank":false
# },
# "axis_ticks":"blank",
# "axis_line":{
# "size":2.8,
# "blank":false
# },
# "legend_background":"blank",
# "legend_text":{
# "family":"Helvetica",
# "size":21.0,
# "blank":false
# },
# "legend_title":"blank",
# "legend_position":"none",
# "panel_background":"blank",
# "panel_grid_minor":"blank",
# "panel_grid_major_x":"blank",
# "panel_grid_major_y":{
# "color":"#CBCBCB",
# "size":1.6799999999999997,
# "blank":false
# },
# "plot_title":{
# "family":"Helvetica",
# "face":"bold",
# "size":33.0,
# "margin":[11.0,0.0,0.0,0.0],
# "blank":false
# },
# "plot_subtitle":{
# "family":"Helvetica",
# "size":26.0,
# "margin":[9.0,0.0,0.0,0.0],
# "blank":false
# },
# "strip_text":{
# "size":26.0,
# "hjust":0.0,
# "blank":false
# }
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Living longer",
# "subtitle":"Life expectancy in China and the US"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "format":"d"
# },{
# "aesthetic":"y",
# "breaks":[0.0,20.0,40.0,60.0,80.0],
# "limits":[0.0,null],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "values":["#FAAB18","#1380A1"]
# },{
# "aesthetic":"x",
# "limits":[1950.0,2011.0]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "tooltips":{
# "formats":[{
# "field":"@year",
# "format":"d"
# }]
# },
# "data_meta":{
# },
# "size":1.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":1980.0,
# "y":45.0,
# "label":"I'm quite a long\nannotation over\nthree rows",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#555555",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":2007.0,
# "y":79.0,
# "label":"US",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#1380A1",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "label_size":0.0,
# "x":2007.0,
# "y":72.0,
# "label":"China",
# "hjust":0.0,
# "vjust":0.5,
# "color":"#FAAB18",
# "fill":"white",
# "family":"Helvetica",
# "size":10.0,
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "x":1979.0,
# "y":45.0,
# "xend":1965.0,
# "yend":43.0,
# "color":"#555555",
# "size":1.0499999999999998,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("c99WIS");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Add a curved line

# %%
multiple_line_plot + \
    geom_curve(x=1979, y=45, xend=1965, yend=43, color='#555555', \
               curvature = -0.2, size=line_size*3/4, tooltips='none')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 multiple_line_plot + \
# ----> 2     geom_curve(x=1979, y=45, xend=1965, yend=43, color='#555555', \
#       3                curvature = -0.2, size=line_size*3/4, tooltips='none')
#
# NameError: name 'geom_curve' is not defined

# %% [markdown]
# ### Add an arrow

# %%
multiple_line_plot + \
    geom_curve(x=1979, y=45, xend=1965, yend=43, color='#555555', \
               curvature = -0.2, size=line_size*3/4, arrow=arrow(), tooltips='none')

# %% [markdown]
# ### Add a line across the whole plot

# %%
multiple_line_plot + \
    geom_hline(yintercept=10, size=line_size, color='red', linetype='dashed', tooltips='none')

# %% [markdown]
# ## Work with small multiples

# %% [markdown]
# ### Facets

# %%
facet_df = df[df.continent != "Americas"].groupby(['continent', 'year']).pop.sum().to_frame().reset_index()
ggplot() + \
    geom_area(aes('year', 'pop', fill='continent'), data=facet_df, size=0) + \
    scale_fill_manual(values=['#FAAB18', '#1380A1', '#990000', '#588300']) + \
    facet_wrap('continent', ncol=5) + \
    scale_y_continuous(breaks=[0, 2000000000, 4000000000], \
                       labels=['0', '2bn', '4bn']) + \
    bbc_theme(x_line='theme') + \
    theme(legend_position='none', axis_text_x=element_blank()) + \
    ggsize(600, 420) + \
    labs(title="Asia's rapid growth", subtitle="Population growth by continent, 1952-2007")

# %% [markdown]
# ### Free scales

# %%
ggplot() + \
    geom_area(aes('year', 'pop', fill='continent'), data=facet_df, size=0) + \
    scale_fill_manual(values=['#FAAB18', '#1380A1', '#990000', '#588300']) + \
    facet_wrap('continent', scales='free') + \
    bbc_theme(x_line='theme') + \
    theme(legend_position='none', axis_text_x=element_blank(), axis_text_y=element_blank()) + \
    ggsize(600, 400) + \
    labs(title="It's all relative", subtitle="Relative population growth by continent, 1952-2007")

# %% [markdown]
# ## Do something else entirely

# %% [markdown]
# ### Increase or decrease margins

# %%
bars_plot + theme(plot_subtitle=element_text(margin=[0, 0, 75, 0]))

# %% [markdown]
# ### Reorder bars by size

# %%
ggplot(bar_df, aes(as_discrete('country', order_by='lifeExp', order=1), 'lifeExp')) + \
    geom_bar(stat='identity', position='identity', fill='#1380A1') + \
    scale_y_continuous(breaks=list(range(0, 81, 20))) + \
    bbc_theme(x_line='theme') + theme(axis_text_y=element_text(angle=0)) + \
    ggsize(600, 450) + \
    coord_flip() + \
    labs(title="Reunion is highest", subtitle="Highest African life expectancy, 2007")

# %% [markdown]
# ### Colour bars conditionally

# %%
colored_bar_df = bar_df.assign(color="#DDDDDD")
colored_bar_df.loc[colored_bar_df["country"] == "Mauritius", 'color'] = "#1380A1"

ggplot(colored_bar_df, aes(as_discrete('country', order_by='lifeExp', order=1), 'lifeExp')) + \
    geom_bar(aes(fill='color'), stat='identity', position='identity') + \
    scale_y_continuous(breaks=list(range(0, 81, 20))) + \
    scale_fill_identity() + \
    bbc_theme(x_line='theme') + theme(axis_text_y=element_text(angle=0)) + \
    ggsize(600, 450) + \
    coord_flip() + \
    labs(title="Reunion is highest", subtitle="Highest African life expectancy, 2007")
