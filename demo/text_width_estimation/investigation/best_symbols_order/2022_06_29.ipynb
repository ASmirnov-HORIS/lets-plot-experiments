# %% [markdown]
# ### Подготовка

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

from lets_plot import *
from lets_plot.mapping import as_discrete
LetsPlot.setup_html()

import os; import sys; sys.path.append(os.path.join(sys.path[0], "..", ".."))
from util import util
# Out:
#             <div id="OqxtsH"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("OqxtsH").appendChild(div);
#                     };
#                     var e = document.getElementById("OqxtsH");
#                     e.appendChild(script);
#                 })()
#             </script>
#             <div id="zB2HxW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("zB2HxW").appendChild(div);
#                     };
#                     var e = document.getElementById("zB2HxW");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def plot_matrix(plots=[], width=400, height=300, columns=2):
    bunch = GGBunch()
    for i in range(len(plots)):
        row = int(i / columns)
        column = i % columns
        bunch.add_plot(plots[i], column * width, row * height, width, height)
    return bunch.show()

# %%
char_widths_df = util.get_df("../../data/char_widths.csv", "train")
char_widths_df
# Out:
#        char_id char     alphabet font_face  font_size font_version  width
# 0           65    A  basic_latin   Courier          9                   9
# 1           66    B  basic_latin   Courier          9                   9
# 2           67    C  basic_latin   Courier          9                   9
# 3           68    D  basic_latin   Courier          9                   9
# 4           69    E  basic_latin   Courier          9                   9
# ...        ...  ...          ...       ...        ...          ...    ...
# 97939    38754    面     japanese   Verdana         20           bi     43
# 97940    38761    革     japanese   Verdana         20           bi     43
# 97941    38936    領     japanese   Verdana         20           bi     43
# 97942    39080    風     japanese   Verdana         20           bi     43
# 97943    39640    高     japanese   Verdana         20           bi     43
#
# [97944 rows x 7 columns]

# %%
char_widths_s = char_widths_df.groupby(["font_face", "font_size", "font_version", "char"]).width.median().astype(int)
char_widths_s
# Out:
# font_face  font_size  font_version  char
# Courier    9                                 9
#                                     !        9
#                                     "        9
#                                     #        9
#                                     $        9
#                                             ..
# Verdana    20         i             面       42
#                                     革       42
#                                     領       42
#                                     風       42
#                                     高       42
# Name: width, Length: 90384, dtype: int64

# %% [markdown]
# ## Шаг №1
#
# Ширины символов пробразуются в "порядки": для каждого символа `X` каждого алфавита и для каждого шрифта `F` порядок - это количество символов этого же алфавита, которые по ширине меньше чем он сам, обозначаемое через `p(X, F)`. После для каждого символа вычисляется `p(X)` - среднее значение `p(X, F)` по всем `F` для данного `X`.

# %%
char_orders_df = util.transform_char_widths_to_orders(char_widths_df)
char_orders_df
# Out:
# alphabet                         basic_latin                               \
# char                                            !     "     #     $     %
# font_face font_size font_version
# Courier   9                              NaN  NaN   NaN   NaN   NaN   NaN
#                     b                    NaN  NaN   NaN   NaN   NaN   NaN
#                     bi                   NaN  NaN   NaN   NaN   NaN   NaN
#                     i                    NaN  NaN   NaN   NaN   NaN   NaN
#           11                             NaN  NaN   NaN   NaN   NaN   NaN
# ...                                      ...  ...   ...   ...   ...   ...
# Verdana   17        i                    3.0  5.0  19.0  82.0  36.0  94.0
#           20                             3.0  8.0  12.0  82.0  38.0  94.0
#                     b                    1.0  6.0  21.0  81.0  37.0  94.0
#                     bi                   0.0  6.0  19.0  76.0  30.0  94.0
#                     i                    3.0  5.0  15.0  82.0  31.0  93.0
#
# alphabet                                                 ... russian        \
# char                                 &    '     (     )  ...       ц     ч
# font_face font_size font_version                         ...
# Courier   9                        NaN  NaN   NaN   NaN  ...     NaN   NaN
#                     b              NaN  NaN   NaN   NaN  ...     NaN   NaN
#                     bi             NaN  NaN   NaN   NaN  ...     NaN   NaN
#                     i              NaN  NaN   NaN   NaN  ...     NaN   NaN
#           11                       NaN  NaN   NaN   NaN  ...     NaN   NaN
# ...                                ...  ...   ...   ...  ...     ...   ...
# Verdana   17        i             65.0  2.0  14.0  14.0  ...    30.0  25.0
#           20                      74.0  0.0  12.0  12.0  ...    60.0  24.0
#                     b             81.0  0.0  14.0  14.0  ...    56.0  23.0
#                     bi            76.0  0.0  13.0  13.0  ...    41.0  21.0
#                     i             65.0  2.0  15.0  15.0  ...    43.0  22.0
#
# alphabet                                                                     \
# char                                 ш      щ     ъ     ы     ь     э     ю
# font_face font_size font_version
# Courier   9                        NaN    NaN   NaN   NaN   NaN   NaN   NaN
#                     b              NaN    NaN   NaN   NaN   NaN   NaN   NaN
#                     bi             NaN    NaN   NaN   NaN   NaN   NaN   NaN
#                     i              NaN    NaN   NaN   NaN   NaN   NaN   NaN
#           11                       NaN    NaN   NaN   NaN   NaN   NaN   NaN
# ...                                ...    ...   ...   ...   ...   ...   ...
# Verdana   17        i             97.0   97.0  30.0  75.0  16.0  20.0  93.0
#           20                      98.0   99.0  60.0  85.0  22.0  20.0  95.0
#                     b             97.0  100.0  64.0  92.0  21.0  15.0  97.0
#                     bi            97.0   99.0  54.0  89.0  19.0  15.0  97.0
#                     i             96.0   99.0  43.0  81.0  18.0  18.0  93.0
#
# alphabet
# char                                 я
# font_face font_size font_version
# Courier   9                        NaN
#                     b              NaN
#                     bi             NaN
#                     i              NaN
#           11                       NaN
# ...                                ...
# Verdana   17        i             25.0
#           20                      24.0
#                     b             23.0
#                     bi            41.0
#                     i             43.0
#
# [168 rows x 583 columns]

# %%
mean_order_df = char_orders_df.describe().loc["mean"].groupby("char").mean().to_frame("mean_order").reset_index()
mean_order_df
# Out:
#     char  mean_order
# 0           1.016204
# 1      !    7.072917
# 2      "   20.559028
# 3      #   45.486111
# 4      $   34.513889
# ..   ...         ...
# 533    面   99.000000
# 534    革   99.000000
# 535    領   99.000000
# 536    風   99.000000
# 537    高   99.000000
#
# [538 rows x 2 columns]

# %% [markdown]
# ## Шаг №2
#
# Полученные значения `p(X)` складываем ровно в `carts_count` корзин.

# %%
carts_count = 10

# %%
mean_order_df["cart_id"] = KMeans(n_clusters=carts_count, random_state=42).fit(mean_order_df[["mean_order"]]).labels_
cart_id_replaces = {
    k: i
    for i, k in enumerate(mean_order_df.groupby("cart_id").mean_order.median().sort_values().keys())
}
mean_order_df = mean_order_df.replace({"cart_id": cart_id_replaces})
mean_order_df
# Out:
#     char  mean_order  cart_id
# 0           1.016204        0
# 1      !    7.072917        0
# 2      "   20.559028        2
# 3      #   45.486111        5
# 4      $   34.513889        3
# ..   ...         ...      ...
# 533    面   99.000000        9
# 534    革   99.000000        9
# 535    領   99.000000        9
# 536    風   99.000000        9
# 537    高   99.000000        9
#
# [538 rows x 3 columns]

# %% [markdown]
# Рисуем `geom_boxplot()` с вариацией `p(X)` для каждой корзины:

# %%
ggplot(mean_order_df, aes(as_discrete("cart_id", order_by="..middle.."), "mean_order")) + geom_boxplot()
# Out:
#    <div id="2FdegO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"@as_discrete@cart_id",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"cart_id",
# "order_by":"..middle.."
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[2.989583333333333,22.944444444444443,48.576388888888886,32.369791666666664,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,99.0,71.53125,13.159722222222221,39.388888888888886,NaN,NaN,58.535714285714285,82.63888888888889],
# "..lower..":[1.5654761904761905,20.09722222222222,47.30357142857143,30.21527777777778,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,99.0,67.59027777777777,10.73611111111111,37.1125992063492,NaN,NaN,58.535714285714285,80.47222222222223],
# "..upper..":[5.439236111111111,23.20138888888889,50.5,32.70238095238095,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,99.0,73.44791666666666,14.253472222222223,40.888888888888886,NaN,NaN,61.22916666666667,86.13194444444444],
# "..ymin..":[0.0,17.70138888888889,44.520833333333336,26.958333333333336,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,99.0,65.83333333333333,8.5,35.951388888888886,NaN,NaN,54.958333333333336,78.09027777777777],
# "..ymax..":[7.25,25.479166666666668,53.53125,35.375,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,99.0,76.20833333333333,17.131944444444443,44.21527777777778,NaN,NaN,64.48611111111111,90.77777777777777],
# "@as_discrete@cart_id":[0.0,2.0,5.0,3.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,9.0,7.0,1.0,4.0,6.0,6.0,6.0,8.0],
# "mean_order":[NaN,NaN,NaN,NaN,92.64930555555556,95.84375,93.27777777777777,102.45138888888889,97.10416666666667,103.31944444444444,103.54861111111111,101.20138888888889,103.90277777777777,93.76388888888889,95.00694444444444,95.73809523809524,95.73809523809524,NaN,NaN,NaN,NaN,54.416666666666664,54.416666666666664,NaN,NaN]
# }
# }]
# };
#            var plotContainer = document.getElementById("2FdegO");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# Рисуем `geom_bar()` с `p(X)` для каждого `X` каждой корзины:

# %%
plot_matrix([
    ggplot(mean_order_df[mean_order_df.cart_id == cart_id]) + \
        geom_bar(aes(as_discrete("char", order_by="mean_order", order=1), "mean_order"), stat='identity') + \
        coord_flip() + ylim(0, 105) + \
        ggtitle("cart_id = {0}".format(cart_id))
    for cart_id in range(carts_count - 1, -1, -1)
])
# Out:
#    <div id="gphahx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 9"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "mean_order":[92.64930555555556,95.84375,93.27777777777777,102.45138888888889,97.10416666666667,103.31944444444444,103.54861111111111,101.20138888888889,103.90277777777777,93.76388888888889,95.00694444444444,99.0,95.73809523809524,95.73809523809524,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0,99.0],
# "@as_discrete@char":["%","@","W","Ж","М","Ш","Щ","Ы","Ю","ш","щ","〜","み","れ","上","不","世","中","主","乏","人","今","仕","代","会","体","供","保","倒","倫","偏","催","傷","再","出","分","別","前","副","割","創","力","加","助","励","動","化","午","協","厳"]
# }
# }],
# "computation_messages":["sampling_pick(n=50) was applied to [bar/identity stat] layer"]
# }
# },{
# "x":400,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[80.47916666666667,80.88194444444444,78.09027777777777,90.77777777777777,80.08333333333333,79.61805555555556,79.61805555555556,78.94444444444444,79.54166666666667,88.94444444444444,81.84027777777777,82.82638888888889,82.25694444444444,82.25694444444444,78.96527777777777,82.63888888888889,82.0,81.54861111111111,87.80555555555556,80.47222222222223,82.75694444444444,86.13194444444444,80.34722222222223,86.16666666666667,87.20833333333333,83.27083333333333,87.51388888888889,84.88095238095238,90.10714285714286,90.10714285714286,84.88095238095238,84.88095238095238,84.88095238095238]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 8"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@char":["G","H","K","M","N","O","Q","U","X","m","w","Д","И","Й","Л","Н","О","П","Ф","Х","Ц","Ъ","Я","ж","ф","ы","ю","す","な","は","や","ハ","バ"]
# }
# }]
# }
# },{
# "x":0,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[74.35416666666667,71.52083333333333,68.17361111111111,72.38194444444444,76.20833333333333,65.83333333333333,73.50694444444444,75.0,71.54166666666667,70.79166666666667,66.60416666666667,66.25,66.53472222222223,72.13888888888889,70.56944444444444,74.89583333333333,67.00694444444444,73.38888888888889]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 7"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@char":["&","A","B","C","D","E","R","V","Y","А","Б","В","К","С","У","Ч","Э","м"]
# }
# }]
# }
# },{
# "x":400,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[59.763888888888886,64.375,60.90277777777778,62.291666666666664,61.44444444444444,55.1875,62.63194444444444,54.958333333333336,61.125,55.52777777777778,61.333333333333336,55.24305555555556,64.20833333333333,62.395833333333336,60.06944444444444,64.48611111111111,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,62.726190476190474,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,54.416666666666664,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,62.726190476190474,58.535714285714285,58.535714285714285,58.535714285714285,54.416666666666664,58.535714285714285,62.726190476190474,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285,62.726190476190474,58.535714285714285,58.535714285714285,58.535714285714285,58.535714285714285]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 6"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@char":["F","P","S","T","Z","Έ","Ή","Ό","Ύ","Ώ","Μ","Φ","Е","Р","Т","Ь","あ","い","か","け","げ","で","の","ぶ","む","め","ん","ガ","キ","ゲ","サ","シ","ジ","ズ","セ","デ","ナ","ネ","パ","ヘ","ベ","ペ","ホ","ボ","ム","ヤ","ル","ー"]
# }
# }]
# }
# },{
# "x":0,
# "y":600,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[45.486111111111114,53.53125,53.46180555555556,53.263888888888886,53.263888888888886,47.388888888888886,51.666666666666664,50.18055555555556,52.95833333333333,49.94444444444444,48.4375,46.81944444444444,48.923611111111114,48.013888888888886,49.59722222222222,48.576388888888886,50.8125,47.361111111111114,49.298611111111114,49.298611111111114,50.5,48.625,47.9375,45.604166666666664,48.15277777777778,44.520833333333336,53.208333333333336,47.30357142857143,47.30357142857143,47.30357142857143,47.30357142857143,47.30357142857143,47.30357142857143]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@char":["#","+","<","=",">","_","d","p","~","Η","Θ","Κ","Ν","Ο","Π","Χ","Ω","ψ","ω","ώ","Г","З","л","р","т","ц","ъ","た","つ","て","に","ケ","チ"]
# }
# }]
# }
# },{
# "x":400,
# "y":600,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[36.60416666666667,36.21875,39.392361111111114,44.21527777777778,44.041666666666664,38.38194444444444,42.833333333333336,40.861111111111114,36.520833333333336,41.31944444444444,36.166666666666664,40.65277777777778,43.076388888888886,38.84027777777778,37.11805555555556,39.388888888888886,39.31944444444444,35.951388888888886,38.791666666666664,39.388888888888886,36.361111111111114,40.875,37.68055555555556,43.145833333333336,40.791666666666664,41.111111111111114,41.19444444444444,40.90277777777778,39.763888888888886,39.47222222222222,37.107142857142854,39.32738095238095,37.107142857142854,37.107142857142854]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 4"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0,105]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@char",
# "y":"mean_order"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"mean_order",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@char":["0","5","7","L","^","b","g","h","k","n","o","q","u","x","y","Ά","Α","Β","Δ","Λ","Ξ","Υ","φ","б","д","и","й","н","п","я","オ","グ","ス","テ"]
# }
# }]
# }
# },{
# "x":0,
# "y":900,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "mean_order":[34.513888888888886,26.958333333333336,32.357638888888886,32.16666666666667,31.65625,35.263888888888886,34.986111111111114,31.3541666666666

# %% [markdown]
# ## Шаг №3
#
# Фиксируем следующие значения:
#
# - `basic_cart_id` - индекс средней по ширине корзины.
#
# - `basic_font` - "Lucida Grande", 20pt, без модификаций.
#
# - `cart_widths` - словарь, в котором каждая корзина получает в качестве ширины медианное значение ширин (в пикселях) всех символов корзины, начертанных базовым шрифтом.
#
# - `basic_width` - значение из `cart_widths`, принадлежащее корзине с индексом `basic_cart_id`.

# %%
basic_cart_id = int(carts_count / 2)
print("Basic cart_id:", basic_cart_id)
basic_font = ("Lucida Grande", 20, "")
print("Basic font:", basic_font)
cart_widths = {
    cart_id: int(char_widths_s.loc[basic_font].loc[mean_order_df[mean_order_df.cart_id == cart_id].char.values].median())
    for cart_id in range(carts_count)
}
print("Cart widths:", cart_widths)
basic_width = cart_widths[basic_cart_id]
print("Basic width:", basic_width)
# Out:
# Basic cart_id: 5
# Basic font: ('Lucida Grande', 20, '')
# Cart widths: {0: 12, 1: 20, 2: 22, 3: 24, 4: 22, 5: 27, 6: 32, 7: 27, 8: 30, 9: 39}
# Basic width: 27

# %% [markdown]
# ## Шаг №4
#
# Вычисляются нормировочные коэффициенты различных шрифтов. Для каждого `F` его нормировочный коэффициент `N(F)` - это отношение медианной ширины "базовой корзины" начертанной шрифтом `F` к `basic_width`.

# %%
ncoeff_s = char_widths_s.to_frame().reset_index().set_index("char").loc[mean_order_df[mean_order_df.cart_id == basic_cart_id].char.values].reset_index().groupby(["font_face", "font_size", "font_version"]).width.median() / basic_width
ncoeff_s
# Out:
# font_face  font_size  font_version
# Courier    9                          0.333333
#                       b               0.370370
#                       bi              0.370370
#                       i               0.333333
#            11                         0.444444
#                                         ...
# Verdana    17         i               1.000000
#            20                         1.148148
#                       b               1.259259
#                       bi              1.259259
#                       i               1.185185
# Name: width, Length: 168, dtype: float64

# %% [markdown]
# ## Шаг №5
#
# С помощью нормировочных коэффициентов восстанавливаются прогнозируемые ширины символов в пикселях: для каждого символа `X` и шрифта `F` шириной становится ширина корзины которой принадлежит символ, умноженная на нормировочный коэффициент данного шрифта.

# %%
char_widths_calc_df = char_widths_s.to_frame().reset_index()\
    .merge(mean_order_df, on="char")\
    .merge(ncoeff_s.to_frame().reset_index(), \
           on=["font_face", "font_size", "font_version"], \
           suffixes=("_original", "_ncoeff"))\
    .assign(width_calc=lambda r: (np.round(r.cart_id.map(cart_widths) * r.width_ncoeff)).astype(int))
char_widths_calc_df.head()
# Out:
#   font_face  font_size font_version char  width_original  mean_order  cart_id  \
# 0   Courier          9                                 9    1.016204        0
# 1   Courier          9                 !               9    7.072917        0
# 2   Courier          9                 "               9   20.559028        2
# 3   Courier          9                 #               9   45.486111        5
# 4   Courier          9                 $               9   34.513889        3
#
#    width_ncoeff  width_calc
# 0      0.333333           4
# 1      0.333333           4
# 2      0.333333           7
# 3      0.333333           9
# 4      0.333333           8

# %%
mean_width_df = char_widths_calc_df.groupby(["cart_id", "char"])[["width_original", "width_calc"]].mean()\
    .assign(width_diff=lambda r: r.width_calc - r.width_original).reset_index()
mean_width_df
# Out:
#      cart_id char  width_original  width_calc  width_diff
# 0          0             8.392857    8.571429    0.178571
# 1          0    !        9.779762    8.571429   -1.208333
# 2          0    '        8.095238    8.571429    0.476190
# 3          0    ,        8.845238    8.571429   -0.273810
# 4          0    .        8.678571    8.571429   -0.107143
# ..       ...  ...             ...         ...         ...
# 533        9    面       26.154762   27.839286    1.684524
# 534        9    革       26.154762   27.839286    1.684524
# 535        9    領       26.154762   27.839286    1.684524
# 536        9    風       26.154762   27.839286    1.684524
# 537        9    高       26.154762   27.839286    1.684524
#
# [538 rows x 5 columns]

# %% [markdown]
# График ошибок: для каждого символа `X` каждой корзины рисуется разница между спрогнозированной шириной и фактической.

# %%
plot_matrix([
    ggplot(mean_width_df[mean_width_df.cart_id == cart_id], \
           aes(as_discrete("char", order_by="width_diff", order=1), "width_diff")) + \
    geom_bar(stat="identity", sampling=sampling_pick(538)) + \
    coord_flip() + ylim(-8, 6) + \
    ggtitle("cart_id = {0}".format(cart_id))
    for cart_id in range(carts_count - 1, -1, -1)
])
# Out:
#    <div id="KELWS6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "width_diff":[4.255952380952383,3.0119047619047628,1.321428571428573,1.529761904761905,4.2738095238095255,0.5476190476190474,0.4702380952380949,2.5119047619047628,0.6785714285714306,5.55952380952381,5.2023809523809526,1.6845238095238102,4.56547619047619,4.56547619047619,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.6845238095238102,1.684 ...
# },
# "mapping":{
# "x":"@as_discrete@char",
# "y":"width_diff"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"width_diff",
# "order":1
# }
# }]
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 9"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-8,6]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "sampling":{
# "name":"pick",
# "n":538
# },
# "data_meta":{
# },
# "data":{
# "@as_discrete@char":["%","@","W","Ж","М","Ш","Щ","Ы","Ю","ш","щ","〜","み","れ","上","不","世","中","主","乏","人","今","仕","代","会","体","供","保","倒","倫","偏","催","傷","再","出","分","別","前","副","割","創","力","加","助","励","動","化","午","協","厳","参","反","叔","号","合","同","名","君","呼","品","善","器","図","埋","売","大","央","奨","女","婦","嫁","字","学","官","害","対","射","尊","尿","屋","山","差","建","式","引","張","形","彼","待","徴","必","怒","意","感","憲","戦","拡","持","指","授","探","擁","改","放","教","敬","数","敵","文","料","新","日","明","普","景","暖","曜","月","本","柔","査","根","椎","極","楽","欠","残","池","況","法","派","溝","演","然","父","物","特","犯","状","狐","狭","現","球","理","生","画","略","癌","発","的","目","省","眠","知","私","移","突","立","端","符","管","築","索","細","組","給","統","続","編","緩","織","罪","置","者","職","脊","腐","自","舗","花","落","葉","虐","血","行","術","衝","装","裏","要","見","覚","言","計","証","評","試","話","謝","議","販","賛","賞","質","身","転","軸","込","近","追","通","連","進","運","部","野","金","鉱","錯","陶","隊","障","隠","雪","電","面","革","領","風","高"]
# }
# }]
# }
# },{
# "x":400,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "width_diff":[1.125,0.7023809523809526,1.4345238095238102,-2.178571428571427,1.0119047619047628,1.2023809523809526,1.2023809523809526,1.2440476190476204,1.1607142857142883,-1.3273809523809526,0.6845238095238102,0.75,0.7380952380952372,0.7380952380952372,1.3095238095238102,0.7023809523809526,1.2023809523809526,0.8452380952380949,0.04166666666666785,1.1607142857142883,0.7321428571428577,0.39285714285714235,1.2142857142857153,0.0297619047619051,0.14285714285714235,0.6845238095238102,0.125,-1.0059523809523796,-1.154761904761905,-1.154761904761905,-1.0059523809523796,-1.0059523809523796,-1.0059523809523796]
# },
# "mapping":{
# "x":"@as_discrete@char",
# "y":"width_diff"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"width_diff",
# "order":1
# }
# }]
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"cart_id = 8"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-8,6]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "sampling":{
# "name":"pick",
# "n":538
# },
# "data_meta":{
# },
# "data":{
# "@as_discrete@char":["G","H","K","M","N","O","Q","U","X","m","w","Д","И","Й","Л","Н","О","П","Ф","Х","Ц","Ъ","Я","ж","ф","ы","ю","す","な","は","や","ハ","バ"]
# }
# }]
# }
# },{
# "x":0,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "width_diff":[-0.04761904761904745,0.4345238095238102,0.9821428571428577,0.16666666666666785,-0.3392857142857153,0.9761904761904745,0.0892857142857153,-0.13095238095238315,0.26190476190476275,0.4345238095238102,1.0357142857142847,0.9821428571428577,0.7261904761904745,0.16666666666666785,0.1964285714285694,-0.2142857142857153,0.9047619047619051,0.0952380952380949]
# },
# "mapping":{
# "x":"@as_discrete@char",
# "y":"width_diff"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"char",
# "order_by":"width_diff",
# "order":1

# %% [markdown]
# ## Шаг №6
#
# Второй `geom_boxplot()` с вариацией спрогнозированных ширин символов для каждой корзины.

# %%
ggplot(char_widths_calc_df, aes(as_discrete("cart_id", order=-1), "width_calc")) + geom_boxplot()
# Out:
#    <div id="2UC4Qv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"@as_discrete@cart_id",
# "y":"width_calc"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"cart_id",
# "order":-1
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[8.0,15.0,18.0,16.0,26.0,18.0,13.0,15.0,21.0,20.0],
# "..lower..":[6.0,11.0,14.0,12.0,20.0,14.0,10.0,11.0,17.0,16.0],
# "..upper..":[11.0,20.0,24.0,21.0,35.0,24.0,18.0,20.0,28.0,27.0],
# "..ymin..":[4.0,7.0,9.0,8.0,13.0,9.0,7.0,7.0,11.0,10.0],
# "..ymax..":[15.0,28.0,34.0,30.0,49.0,34.0,25.0,28.0,40.0,38.0],
# "@as_discrete@cart_id":[0.0,2.0,5.0,3.0,9.0,7.0,1.0,4.0,6.0,8.0],
# "width_calc":[NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN]
# }
# }]
# };
#            var plotContainer = document.getElementById("2UC4Qv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
