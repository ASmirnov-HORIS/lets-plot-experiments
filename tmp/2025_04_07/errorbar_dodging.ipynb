# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="zwX33G"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# ### 1. One category

# %%
data1 = {
    'xcat': ['x', 'x'],
    'xval': [0, 0],
    'ymin': [-2, -1],
    'ymax': [1, 2],
    'g': ['a', 'b'],
}

gggrid([
    ggplot(data1) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g')) + \
        ggtitle("x: discrete\nposition: default"),
    ggplot(data1) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g'), position='dodge') + \
        ggtitle("x: discrete\nposition: 'dodge'"),
    ggplot(data1) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g'), position=position_dodge(width=.95)) + \
        ggtitle("x: discrete\nposition: position_dodge(width=.95)"),
    ggplot(data1) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g')) + \
        ggtitle("x: continuous\nposition: default"),
    ggplot(data1) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g'), position='dodge') + \
        ggtitle("x: continuous\nposition: 'dodge'"),
    ggplot(data1) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g'), position=position_dodge(width=.95)) + \
        ggtitle("x: continuous\nposition: position_dodge(width=.95)"),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="udere1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("udere1");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# ...

# %% [markdown]
# ### 2. Few categories

# %%
data2 = {
    'xcat': ['x', 'x', 'y', 'y'],
    'xval': [0, 0, 1, 1],
    'ymin': [-2, -1, -2, -1],
    'ymax': [1, 2, 1, 2],
    'g': ['a', 'b', 'a', 'b'],
}

gggrid([
    ggplot(data2) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g')) + \
        ggtitle("x: discrete\nposition: default"),
    ggplot(data2) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g'), position='dodge') + \
        ggtitle("x: discrete\nposition: 'dodge'"),
    ggplot(data2) + geom_errorbar(aes(x='xcat', ymin='ymin', ymax='ymax', color='g'), position=position_dodge(width=.95)) + \
        ggtitle("x: discrete\nposition: position_dodge(width=.95)"),
    ggplot(data2) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g')) + \
        ggtitle("x: continuous\nposition: default"),
    ggplot(data2) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g'), position='dodge') + \
        ggtitle("x: continuous\nposition: 'dodge'"),
    ggplot(data2) + geom_errorbar(aes(x='xval', ymin='ymin', ymax='ymax', color='g'), position=position_dodge(width=.95)) + \
        ggtitle("x: continuous\nposition: position_dodge(width=.95)"),
], ncol=3)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="5xg18v"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("5xg18v");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# ...
