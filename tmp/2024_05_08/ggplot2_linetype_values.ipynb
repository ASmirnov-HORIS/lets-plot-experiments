# %%
library(ggplot2)

# %%
ggplot() +
    geom_line(aes(x = c(0, 1), y = c(0, 0)), linetype = 'twodash', linewidth = 12) +
    geom_line(aes(x = c(0, 1), y = c(0.025, 0.025)), linetype = "2262", linewidth = 12, color = "red")
# Out:
# plot without title
