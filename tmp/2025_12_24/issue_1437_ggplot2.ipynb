# %% [markdown]
# # Explore [#1437](https://github.com/JetBrains/lets-plot/issues/1437)

# %%
library(ggplot2)

# %%
head(iris, 2)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa

# %% [markdown]
# ## Default

# %%
ggplot(iris, aes(x = Sepal.Length)) +
    geom_histogram(bins = 10) +
    facet_wrap(vars(Species), ncol = 1)
# Out:
# plot without title

# %% [markdown]
# ## Free scales

# %%
ggplot(iris, aes(Sepal.Length)) +
    geom_histogram(bins = 10) +
    facet_wrap(vars(Species), ncol = 1, scales = "free")
# Out:
# plot without title

# %% [markdown]
# ## Free scales and drop

# %% [markdown]
# ### `drop = "none"`

# %%
ggplot(iris, aes(Sepal.Length)) +
    geom_histogram(bins = 10, drop = "none") +
    facet_wrap(vars(Species), ncol = 1, scales = "free")
# Out:
# plot without title

# %% [markdown]
# ### `drop = "all"`

# %%
ggplot(iris, aes(Sepal.Length)) +
    geom_histogram(bins = 10, drop = "all") +
    facet_wrap(vars(Species), ncol = 1, scales = "free")
# Out:
# plot without title
