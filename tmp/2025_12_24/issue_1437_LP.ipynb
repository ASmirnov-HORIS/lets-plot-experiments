# %% [markdown]
# # Explore [#1437](https://github.com/JetBrains/lets-plot/issues/1437)

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#         <div id="A7wX34"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/refs/heads/master/data/iris.csv")
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# ## Default

# %%
ggplot(df, aes(x="sepal_length")) + \
    geom_histogram(bins=10) + \
    facet_wrap("species", ncol=1)
# Out:
#    <div id="kAxn38" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("kAxn38");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"sepal_length"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"sepal_length"
# },{
# "type":"float",
# "column":"sepal_width"
# },{
# ...

# %% [markdown]
# ## Free scales

# %%
ggplot(df, aes(x="sepal_length")) + \
    geom_histogram(bins=10) + \
    facet_wrap("species", ncol=1, scales="free")
# Out:
#    <div id="fyAsLi" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("fyAsLi");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"sepal_length"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"sepal_length"
# },{
# "type":"float",
# "column":"sepal_width"
# },{
# ...

# %% [markdown]
# ## Free scales and zero threshold

# %%
ggplot(df, aes(x="sepal_length")) + \
    geom_histogram(bins=10, threshold=0) + \
    facet_wrap("species", ncol=1, scales="free")
# Out:
#    <div id="TwDoKE" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("TwDoKE");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"sepal_length"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"sepal_length"
# },{
# "type":"float",
# "column":"sepal_width"
# },{
# ...
