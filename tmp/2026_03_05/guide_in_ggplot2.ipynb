# %%
library(ggplot2)

# %%
p <- ggplot(mtcars, aes(wt, mpg, colour = hp)) + geom_point(size = 3)

# %%
p + scale_colour_gradient(guide = "colourbar")
# Out:
# plot without title

# %%
p + scale_colour_gradient(guide = "legend")
# Out:
# plot without title
