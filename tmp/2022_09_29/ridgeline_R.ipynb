# %%
library(ggplot2)
library(ggridges)

# %% [markdown]
# ## Equidistant ridges

# %%
df1 <- data.frame(
    x = c(1, 2, 3, 1, 2, 3, 1, 2, 3),
    y = c(0, 0, 0, 2, 2, 2, 4, 4, 4),
    height = c(0.5, 1, 0.5, 0.5, 1, 0.5, 0.5, 1, 0.5)
)

# %% [markdown]
# ### `geom_ridgeline()` default

# %%
ggplot(df1) +
    geom_ridgeline(aes(x, y, height = height, group = y))
# Out:
# plot without title

# %% [markdown]
# ### `geom_ridgeline()` with `scale = 2`

# %%
ggplot(df1) +
    geom_ridgeline(aes(x, y, height = height, group = y), scale = 2)
# Out:
# plot without title

# %% [markdown]
# ### `geom_density_ridges()` with `stat = 'identity'`

# %%
ggplot(df1) +
    geom_density_ridges(aes(x, y, height = height, group = y), stat = 'identity')
# Out:
# plot without title

# %% [markdown]
# ### `geom_density_ridges()` with `stat = 'identity'` and `scale = 1`

# %%
ggplot(df1) +
    geom_density_ridges(aes(x, y, height = height, group = y), scale = 1, stat = 'identity')
# Out:
# plot without title

# %% [markdown]
# ## Non-equidistant ridges

# %%
df2 <- data.frame(
    x = c(1, 2, 3, 1, 2, 3, 1, 2, 3),
    y = c(0, 0, 0, 2, 2, 2, 3, 3, 3),
    height = c(0.5, 1, 0.5, 0.5, 1, 0.5, 0.5, 1, 0.5)
)

# %% [markdown]
# ### `geom_ridgeline()` default

# %%
ggplot(df2) +
    geom_ridgeline(aes(x, y, height = height, group = y))
# Out:
# plot without title

# %% [markdown]
# ### `geom_ridgeline()` with `scale = 2`

# %%
ggplot(df2) +
    geom_ridgeline(aes(x, y, height = height, group = y), scale = 2)
# Out:
# plot without title

# %% [markdown]
# ### `geom_density_ridges()` with `stat = 'identity'`

# %%
ggplot(df2) +
    geom_density_ridges(aes(x, y, height = height, group = y), stat = 'identity')
# Out:
# plot without title

# %% [markdown]
# ### `geom_density_ridges()` with `stat = 'identity'` and `scale = 1`

# %%
ggplot(df2) +
    geom_density_ridges(aes(x, y, height = height, group = y), scale = 1, stat = 'identity')
# Out:
# plot without title
