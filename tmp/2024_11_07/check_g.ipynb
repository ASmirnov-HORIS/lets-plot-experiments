# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="31fhKd"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("31fhKd").appendChild(div);
#                     };
#                     var e = document.getElementById("31fhKd");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def plot_by_format(format_pattern):
    def plot(type):
        value = 123.45678901
        dmin, dmax = -4, 2
        label_format = None if type is None else format_pattern.format(type)
        title = "Default formatting" if type is None else "format=\"{0}\"".format(label_format)
        subtitle = "" if type is None else "type='{0}'".format(type)
        values = [value * 10**d for d in range(dmin, dmax + 1)]
        return ggplot({'v': values}, aes(y='v')) + \
            geom_label(aes(label='v'), label_format=label_format) + \
            scale_y_log10(limits=[value * 10**(dmin - 1), value * 10**(dmax + 1)]) + \
            ggtitle(title, subtitle)
    return plot

plot1 = plot_by_format(",.2~{0}")
plot2 = plot_by_format("~{0}")

# %%
plot1("g")
# Out:
#    <div id="IcUnVy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("IcUnVy");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "v":[0.012345678901,0.12345678901,1.2345678901,12.345678901,123.45678901,1234.5678900999999,12345.678901]
# },
# "mapping":{
# "y":"v"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"v"
# }]
# },
# "ggtitle":{
# "text":"format=\",.2~g\"",
# "subtitle":"type='g'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0.0012345678901,123456.78901],
# "trans":"log10"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "label":"v"
# },
# "data_meta":{
# },
# "label_format":",.2~g",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
plot1("f")
# Out:
#    <div id="Xu6J86"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Xu6J86");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "v":[0.012345678901,0.12345678901,1.2345678901,12.345678901,123.45678901,1234.5678900999999,12345.678901]
# },
# "mapping":{
# "y":"v"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"v"
# }]
# },
# "ggtitle":{
# "text":"format=\",.2~f\"",
# "subtitle":"type='f'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0.0012345678901,123456.78901],
# "trans":"log10"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "label":"v"
# },
# "data_meta":{
# },
# "label_format":",.2~f",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
plot2("g")
# Out:
#    <div id="TzjakK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("TzjakK");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "v":[0.012345678901,0.12345678901,1.2345678901,12.345678901,123.45678901,1234.5678900999999,12345.678901]
# },
# "mapping":{
# "y":"v"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"v"
# }]
# },
# "ggtitle":{
# "text":"format=\"~g\"",
# "subtitle":"type='g'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0.0012345678901,123456.78901],
# "trans":"log10"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "label":"v"
# },
# "data_meta":{
# },
# "label_format":"~g",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
plot2("f")
# Out:
#    <div id="UCrOCl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("UCrOCl");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "v":[0.012345678901,0.12345678901,1.2345678901,12.345678901,123.45678901,1234.5678900999999,12345.678901]
# },
# "mapping":{
# "y":"v"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"v"
# }]
# },
# "ggtitle":{
# "text":"format=\"~f\"",
# "subtitle":"type='f'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[0.0012345678901,123456.78901],
# "trans":"log10"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "label":"v"
# },
# "data_meta":{
# },
# "label_format":"~f",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
