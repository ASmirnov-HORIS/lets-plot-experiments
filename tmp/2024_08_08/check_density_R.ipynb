# %%
library(ggplot2)

# %%
df <- data.frame(x = c(-.5, 0, 0, .5))

# %%
# area of plot: (0.5 + 1 + 0.5) * 0.5 = 1
ggplot(df, aes(x = x)) + geom_histogram(aes(y = after_stat(density)), binwidth = .5)
# Out:
# plot without title
