# %%
from lets_plot import *
from lets_plot.bistro import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="ONV14J"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
data = {
    'cat': ['A', 'B'],
    'val': [1, 2],
}

# %%
waterfall_plot(data, 'cat', 'val', relative_tooltips=layer_tooltips().line("@cat/@..xlabel.."))
# Out:
#    <div id="oqD6v6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cat":["A","B"]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "name":"cat",
# "breaks":[0.0,1.0,2.0],
# "labels":["A","B","Total"]
# },{
# "aesthetic":"y",
# "name":"val"
# },{
# "aesthetic":"color",
# "name":"Flow type",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"fill",
# "name":"Flow type",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "..x..":[0.0,1.0,2.0],
# "..y..":[1.0,3.0,3.0],
# "..radius..":[0.09999999999999998,0.09999999999999998,0.0]
# },
# "mapping":{
# "x":"..x..",
# "y":"..y..",
# "radius":"..radius.."
# },
# "angle":0.0,
# "position":{
# "name":"nudge",
# "x":0.45
# }
# },{
# "geom":"crossbar",
# "data":{
# "..x..":[0.0,1.0,2.0],
# ...

# %%
waterfall_plot(data, 'cat', 'val', relative_tooltips=layer_tooltips().line("@..xlabel../@..xlabel.."))
# Out:
#    <div id="UoQj4Q"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "name":"cat",
# "breaks":[0.0,1.0,2.0],
# "labels":["A","B","Total"]
# },{
# "aesthetic":"y",
# "name":"val"
# },{
# "aesthetic":"color",
# "name":"Flow type",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# },{
# "aesthetic":"fill",
# "name":"Flow type",
# "breaks":["Increase","Decrease","Total"],
# "values":["#4daf4a","#e41a1c","#377eb8"]
# }],
# "layers":[{
# "geom":"spoke",
# "data":{
# "..x..":[0.0,1.0,2.0],
# "..y..":[1.0,3.0,3.0],
# "..radius..":[0.09999999999999998,0.09999999999999998,0.0]
# },
# "mapping":{
# "x":"..x..",
# "y":"..y..",
# "radius":"..radius.."
# },
# "angle":0.0,
# "position":{
# "name":"nudge",
# "x":0.45
# }
# },{
# "geom":"crossbar",
# "data":{
# "..x..":[0.0,1.0,2.0],
# "..xlabel..":["A","B","Total"],
# ...
