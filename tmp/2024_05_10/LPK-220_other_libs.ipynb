# %%
import sys
# !conda install --yes --prefix {sys.prefix} bokeh jupyter_bokeh seaborn plotly
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - jetbrains
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/asmirnov/Applications/miniconda3/envs/lets-plot-experiments
#
#   added / updated specs:
#     - bokeh
#     - jupyter_bokeh
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.12.2             |  py310h06a4308_0         491 KB
#     ------------------------------------------------------------
#                                            Total:         491 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/linux-64::seaborn-0.12.2-py310h06a4308_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pandas as pd

# %%
x = [-1, 1, 1, -1, -1]
y = [-1, -1, 1, 1, -1]
data = {'x': x, 'y': y}
df = pd.DataFrame(data)
df
# Out:
#    x  y
# 0 -1 -1
# 1  1 -1
# 2  1  1
# 3 -1  1
# 4 -1 -1

# %% [markdown]
# ## Bokeh

# %%
import bokeh.io
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show

bokeh.io.output_notebook()

def get_plot(line_dash, line_width, line_dash_offset):
    p = figure(title="line_dash={0}, line_width={1}, line_dash_offset={2}".format(line_dash, line_width, line_dash_offset))
    p.line(x, y, line_dash=line_dash, line_width=line_width, line_dash_offset=line_dash_offset)
    return p

g = gridplot(
    [
        [
            get_plot("2", 2, 0),
            get_plot("2", 20, 0),
        ],
        [
            get_plot("20", 2, 0),
            get_plot("20", 20, 0),
        ],
        [
            get_plot("20", 20, 10),
            get_plot("20", 20, 20),
        ],
    ],
    width=400,
    height=400
)

show(g)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a4f18b09-8e54-445d-8121-006984347477">Loading BokehJS ...</span>
#     </div>
#   <div id="ff346548-a688-498e-93d2-fba419818512" data-root-id="p3940" style="display: contents;"></div>

# %% [markdown]
# ## Seaborn

# %%
from seaborn.objects import Path, Plot

Plot(df, "x", "y").add(Path(linewidth=20, linestyle="dotted"))
# Out:
# /home/asmirnov/Applications/miniconda3/envs/lets-plot-experiments/lib/python3.10/site-packages/seaborn/_core/plot.py:1491: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# ## Plotly

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px

group = pd.DataFrame({'Hour': {0: 7, 1: 7, 2: 7, 3: 8, 4: 8, 5: 8},
 'Level': {0: 'H', 1: 'M', 2: 'L', 3: 'H', 4: 'M', 5: 'L'},
 'value': {0: 1.435,
  1: 3.1239999999999997,
  2: 5.577999999999999,
  3: 0.435,
  4: 2.124,
  5: 4.578}})

import plotly.graph_objects as go
fig = px.line(
    group, 
    x="Hour", 
    y="value",
    color='Level', 
    title='Graph',
    category_orders={'Level':['H','M','L']},
    color_discrete_map={'H':'royalblue','M':'orange','L':'firebrick'},
    line_dash='Level'
)
  
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_68.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
