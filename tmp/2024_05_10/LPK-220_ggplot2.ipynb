# %%
library(ggplot2)

# %%
ggplot() +
    geom_boxplot(aes(
        x = c("x", "x", "x", "x", "x", "x", "x", "x"),
        y = c(1, 2, 3, 4, 3, 4, 5, 6)
    ), linetype = 'dotted', size = 2.5) +
    theme_minimal()
# Out:
# plot without title

# %%
ggplot() +
    geom_boxplot(aes(
        x = c("x", "x", "x", "x", "x", "x", "x", "x"),
        y = c(1, 2, 3, 4, 3, 4, 5, 6)
    ), linetype = 'dotted', size = 8, fatten = 0) +
    theme_minimal()
# Out:
# plot without title

# %%
ggplot() +
    geom_boxplot(aes(
        x = c("x", "x", "x", "x", "x", "x", "x", "x"),
        y = c(1, 2, 3, 4, 3, 4, 5, 6)
    ), linetype = 'dotted', size = 11, fatten = 0) +
    theme_minimal()
# Out:
# plot without title

# %%
ggplot() +
    geom_boxplot(aes(
        x = c("x", "x", "x", "x", "x", "x", "x", "x"),
        y = c(1, 2, 3, 4, 3, 4, 5, 6)
    ), linetype = 'dotted', size = 14, fatten = 0) +
    theme_minimal()
# Out:
# plot without title
