# %%
library(ggplot2)

# %%
ggplot() + geom_text(aes(x = 0, y = 0, label = "a"))
# Out:
# plot without title

# %%
ggplot() + geom_text(aes(x = 0, y = 0, label = "a")) + coord_flip()
# Out:
# plot without title
