# %%
from lets_plot import *

# %%
LetsPlot.setup_html(no_js=True, offline=True)

# %%
data = {'xmin': [-3, -1], 'xmax': [1, 3], 'ymin': [-.5, -.5], 'ymax': [.5, .5], 'g': ['a', 'b']}

# %%
def rect_plot(*, alpha=1):
    return ggplot(data) + \
        geom_rect(aes(xmin='xmin', xmax='xmax', ymin='ymin', ymax='ymax', color='g', fill='g'), alpha=alpha, size=10) + \
        ggtitle("geom_rect()", "alpha={0}".format(alpha))

def band_plot(*, alpha=1):
    return ggplot(data) + \
        geom_band(aes(xmin='xmin', xmax='xmax', color='g', fill='g'), alpha=alpha, size=10) + \
        ggtitle("geom_band()", "alpha={0}".format(alpha))

# %%
gggrid([
    rect_plot(),
    rect_plot(alpha=.25),
    band_plot(),
    band_plot(alpha=.25),
], ncol=2)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="900.0" height="600.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pOiNgd3 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pOiNgd3 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pOiNgd3 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pOiNgd3 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# ...
