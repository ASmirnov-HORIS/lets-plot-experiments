# %%
library(ggplot2)

# %%
df <- data.frame(
    x = c(0, 1, 9, 10),
    y = c(0, 19, 1, 0)
)

# %%
ggplot(df, aes(x, y)) +
    geom_hex(binwidth = c(10, 10), linewidth = .5) +
    geom_point(color = "red")
# Out:
# plot without title
