# %%
library(ggplot2)

# %%
data = data.frame(
    x = c(0, 1, 2, 3),
    y = c(-2, 1, -1, 2)
)

# %%
p <- ggplot(data, aes(x, y)) + geom_point()
p
# Out:
# plot without title

# %%
p + xlim(1, 2)
# Out:
# Warning message:
# "Removed 2 rows containing missing values (`geom_point()`)."
# plot without title
