# %%
library(ggplot2)

# %%
ggplot() +
    geom_pointrange(aes(x = -1, y = 0, ymin = -1, ymax = 1), shape=21, fill="red", size = 10) +
    geom_pointrange(aes(x = 0, y = 0, ymin = -1, ymax = 1), shape=21, fill="red", size = 10, stroke=10) +
    geom_point(aes(x = 1, y = 0), shape=21, fill="red", size=40, stroke=10) +
    xlim(-3, 3)
# Out:
# plot without title
