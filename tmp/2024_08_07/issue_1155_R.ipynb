# %%
library(ggplot2)

# %%
df <- data.frame(x = c(0, 1, 1, 2, 2, 2, 3, 3, 4))

# %%
p = ggplot(df, aes(x = x)) + geom_histogram(aes(y = after_stat(density)), binwidth = 1)
p
# Out:
# plot without title

# %%
p + scale_y_continuous(labels = scales::percent_format())
# Out:
# plot without title
