# %%
library(ggplot2)
df <- data.frame(
    x = c(1, 1, 0, 0),
    g = c("A", "B", "C", "D")
)
ggplot(df) +
    geom_bar(aes(x = x, fill = g)) +
    scale_x_discrete() +
    theme(axis.text.x = element_text())
# Out:
# plot without title
