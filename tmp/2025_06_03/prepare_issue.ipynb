# %%
from lets_plot import *

# %%
LetsPlot.setup_html(offline=True, no_js=True)

# %%
ggplot() + geom_text(x=0, label=r"\(A^{B_{C \cdot D}}+E\)", size=20, label_format="{}")
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #ppJRo0q .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #ppJRo0q .plot-subtitle {
# fill: #474747;
# font-weight: normal;
# ...

# %%
ggplot() + geom_text(x=0, label=r"\(A^{B_{C \cdot D}}}}+E\)", size=20, label_format="{}")
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#             <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pRvq1cg .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pRvq1cg .plot-subtitle {
# fill: #474747;
# font-weight: normal;
# ...
