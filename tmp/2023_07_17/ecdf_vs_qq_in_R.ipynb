# %%
library(ggplot2)

# %%
set.seed(42)
df <- data.frame(v = rt(200, df = 5))
head(df)
# Out:
#   v
# 1  1.91513709
# 2  0.08784221
# 3 -0.07732699
# 4 -0.06175931
# 5 -0.04798092
# 6  5.02304550

# %%
ggplot(df, aes(v)) + stat_ecdf(geom = "step")
# Out:
# plot without title

# %%
ggplot(df, aes(sample = v)) + stat_qq(geom = "step", distribution = stats::qunif) + coord_flip()
# Out:
# plot without title
