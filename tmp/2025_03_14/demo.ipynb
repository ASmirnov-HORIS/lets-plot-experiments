# %%
from lets_plot import *
from lets_plot.bistro import *

# %%
LetsPlot.setup_html(no_js=True)

# %%
ggplot() + geom_point(x=0)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pYfZWZn .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pYfZWZn .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pYfZWZn .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pYfZWZn .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# ...

# %%
waterfall_plot({'x': ['a', 'b'], 'y': [10, -2]}, 'x', 'y')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pmz3E8N .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pmz3E8N .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pmz3E8N .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pmz3E8N .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# ...

# %%
ggplot() + geom_line(aes(x=[0, 1, 2, 3, 4], y=[1, 2, 3, 1, 2])) + coord_polar()
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pMhJmQY .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pMhJmQY .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pMhJmQY .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pMhJmQY .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# ...

# %%
ggplot() + geom_line(aes(x=[0, 1, 2, 3, 4], y=[1, 2, 3, 1, 2])) + ggtb()
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #p7oJZ1H .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #p7oJZ1H .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p7oJZ1H .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p7oJZ1H .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# ...
