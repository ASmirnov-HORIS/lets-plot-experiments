# %%
library(ggplot2)

# %%
ggplot() + geom_point(aes(x = 0, y = 0), shape = 21, size = 180, stroke = 10, fill = "red")
# Out:
# plot without title

# %%
ggplot() + geom_dotplot(aes(x = 0), binwidth = 1, fill = "red", stroke = 10)
# Out:
# plot without title
