# %%
library(ggplot2)

# %%
df <- data.frame(x = c("A", "B", "C", "D"))
ggplot(df) +
    geom_boxplot(
        linetype = "dotted",
        size = 2.5,
        aes(x = x, lower = 25, middle = 50, upper = 75, ymin = 0, ymax = 100),
        stat = "identity"
    )
# Out:
# plot without title
