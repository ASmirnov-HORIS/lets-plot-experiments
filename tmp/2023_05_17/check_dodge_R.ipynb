# %%
library(ggplot2)

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1),
    y = c(2, -2),
    g = c('a', 'b')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge(width = 0.95), size = 5) +
    ggtitle("position='dodge'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1),
    y = c(2, -2),
    g = c('a', 'b')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge2') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge2(width = 0.95), size = 5) +
    ggtitle("position='dodge2'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'b')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge(width = 0.95), size = 5) +
    ggtitle("position='dodge'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'b')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge2') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge2(width = 0.95), size = 5) +
    ggtitle("position='dodge2'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'a')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge(width = 0.95), size = 5) +
    ggtitle("position='dodge'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1),
    ymin = c(-3, -1),
    lower = c(-2, 0),
    middle = c(-1, 1),
    upper = c(0, 2),
    ymax = c(1, 3),
    g = c('a', 'b')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'a')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g),
                 data = boxes_df, stat = 'identity', position = 'dodge2') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge2(width = 0.95), size = 5) +
    ggtitle("position='dodge2'")
# Out:
# plot without title

# %%
boxes_df <- data.frame(
    x = c(0, 1, 1),
    ymin = c(-3, -1, -1),
    lower = c(-2, 0, 0),
    middle = c(-1, 1, 1),
    upper = c(0, 2, 2),
    ymax = c(1, 3, 3),
    g = c('a', 'b', 'a')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'a')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g, group = g),
                 data = boxes_df, stat = 'identity', position = 'dodge') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge(width = 0.95), size = 5) +
    ggtitle("position='dodge'")
# Out:
# ERROR while rich displaying an object: Error in `geom_boxplot()`:
# ! Problem while converting geom to grob.
# i Error occurred in the 1st layer.
# Caused by error in `draw_group()`:
# ! Can only draw one boxplot per group
# i Did you forget `aes(group = ...)`?
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
# ...

# %%
boxes_df <- data.frame(
    x = c(0, 1, 1),
    ymin = c(-3, -1, -1),
    lower = c(-2, 0, 0),
    middle = c(-1, 1, 1),
    upper = c(0, 2, 2),
    ymax = c(1, 3, 3),
    g = c('a', 'b', 'a')
)
points_df <- data.frame(
    x = c(0, 1, 1),
    y = c(2, -2, -3),
    g = c('a', 'b', 'a')
)
ggplot() +
    geom_boxplot(aes(x, ymin = ymin, lower = lower, middle = middle, upper = upper, ymax = ymax, color = g, group = g),
                 data = boxes_df, stat = 'identity', position = 'dodge2') +
    geom_point(aes(x, y, color = g), data = points_df, position = position_dodge2(width = 0.95), size = 5) +
    ggtitle("position='dodge2'")
# Out:
# ERROR while rich displaying an object: Error in `geom_boxplot()`:
# ! Problem while converting geom to grob.
# i Error occurred in the 1st layer.
# Caused by error in `draw_group()`:
# ! Can only draw one boxplot per group
# i Did you forget `aes(group = ...)`?
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
# ...
