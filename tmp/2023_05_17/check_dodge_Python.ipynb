# %%
from lets_plot import *
LetsPlot.setup_html(offline=True, no_js=True)

# %%
boxes_data = dict(
    x = [0, 1],
    ymin = [-3, -1],
    lower = [-2, 0],
    middle = [-1, 1],
    upper = [0, 2],
    ymax = [1, 3],
    g = ['a', 'b']
)
points_data = dict(
    x = [0, 1],
    y = [2, -2],
    g = ['a', 'b']
)
ggplot() + \
    geom_boxplot(aes('x', ymin='ymin', lower='lower', middle='middle', upper='upper', ymax='ymax', color='g'), \
                 data=boxes_data, stat='identity', position='dodge') + \
    geom_point(aes('x', 'y', color='g'), data=points_data, position=position_dodge(width=.95), size=5)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #paFKjT3 .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #paFKjT3 .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #paFKjT3 .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #paFKjT3 .legend-title {
#    fill: #474747;
# ...

# %%
boxes_data = dict(
    x = [0, 1],
    ymin = [-3, -1],
    lower = [-2, 0],
    middle = [-1, 1],
    upper = [0, 2],
    ymax = [1, 3],
    g = ['a', 'b']
)
points_data = dict(
    x = [0, 1, 1],
    y = [2, -2, -3],
    g = ['a', 'b', 'b']
)
ggplot() + \
    geom_boxplot(aes('x', ymin='ymin', lower='lower', middle='middle', upper='upper', ymax='ymax', color='g'), \
                 data=boxes_data, stat='identity', position='dodge') + \
    geom_point(aes('x', 'y', color='g'), data=points_data, position=position_dodge(width=.95), size=5)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pdlzQcd .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pdlzQcd .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pdlzQcd .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pdlzQcd .legend-title {
#    fill: #474747;
# ...

# %%
boxes_data = dict(
    x = [0, 1],
    ymin = [-3, -1],
    lower = [-2, 0],
    middle = [-1, 1],
    upper = [0, 2],
    ymax = [1, 3],
    g = ['a', 'b']
)
points_data = dict(
    x = [0, 1, 1],
    y = [2, -2, -3],
    g = ['a', 'b', 'a']
)
ggplot() + \
    geom_boxplot(aes('x', ymin='ymin', lower='lower', middle='middle', upper='upper', ymax='ymax', color='g'), \
                 data=boxes_data, stat='identity', position='dodge') + \
    geom_point(aes('x', 'y', color='g'), data=points_data, position=position_dodge(width=.95), size=5)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pp6eEDQ .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pp6eEDQ .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pp6eEDQ .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pp6eEDQ .legend-title {
#    fill: #474747;
# ...

# %%
boxes_data = dict(
    x = [0, 1, 1],
    ymin = [-3, -1, -1],
    lower = [-2, 0, 0],
    middle = [-1, 1, 1],
    upper = [0, 2, 2],
    ymax = [1, 3, 3],
    g = ['a', 'b', 'a']
)
points_data = dict(
    x = [0, 1, 1],
    y = [2, -2, -3],
    g = ['a', 'b', 'a']
)
ggplot() + \
    geom_boxplot(aes('x', ymin='ymin', lower='lower', middle='middle', upper='upper', ymax='ymax', color='g'), \
                 data=boxes_data, stat='identity', position='dodge') + \
    geom_point(aes('x', 'y', color='g'), data=points_data, position=position_dodge(width=.95), size=5)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pgrzkau .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pgrzkau .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pgrzkau .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pgrzkau .legend-title {
#    fill: #474747;
# ...

# %%
boxes_data = dict(
    x = [0, 1, 1],
    ymin = [-3, -1, -1],
    lower = [-2, 0, 0],
    middle = [-1, 1, 1],
    upper = [0, 2, 2],
    ymax = [1, 3, 3],
    g = ['a', 'b', 'a']
)
points_data = dict(
    x = [0, 1, 1],
    y = [2, -2, -3],
    g = ['a', 'b', 'a']
)
ggplot() + \
    geom_boxplot(aes('x', ymin='ymin', lower='lower', middle='middle', upper='upper', ymax='ymax', color='g'), \
                 data=boxes_data, stat='identity', position='dodge') + \
    geom_point(aes('x', 'y', color='g'), data=points_data, position='identity', size=5)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #peM0O1o .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #peM0O1o .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #peM0O1o .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #peM0O1o .legend-title {
#    fill: #474747;
# ...
