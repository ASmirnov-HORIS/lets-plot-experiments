# %%
library(ggplot2)

# %%
data <- data.frame(
    x = c(1, 2, 3, 4),
    y = c(1, 2, 5, 6)
)

# %%
ggplot(data, aes(x, y)) + geom_step()
# Out:
# plot without title

# %%
ggplot(data, aes(x, y)) + geom_step() + coord_flip()
# Out:
# plot without title
