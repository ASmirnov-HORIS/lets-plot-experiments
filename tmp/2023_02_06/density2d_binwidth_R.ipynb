# %%
library(ggplot2)

# %%
df <- data.frame(
    x = c(100, 200),
    y = c(100, 200)
)

# %%
ggplot(df, aes(x, y)) + geom_density2d(binwidth = 0.000005)
# Out:
# plot without title

# %%
ggplot(df, aes(x, y)) + geom_density_2d_filled(aes(fill = after_stat(level)), binwidth = 0.000005)
# Out:
# plot without title
