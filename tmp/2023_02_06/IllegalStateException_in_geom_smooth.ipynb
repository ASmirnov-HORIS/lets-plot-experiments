# %%
import numpy as np

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="CrLNOR"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
ggplot({'x': [], 'y': []}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="UsgXK1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..ymin..":[],
# "..ymax..":[],
# "x":[],
# "y":[]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("UsgXK1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot({'x': [0], 'y': [0]}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="Pjsw0M"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..ymin..":[],
# "..ymax..":[],
# "x":[],
# "y":[]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Pjsw0M");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot({'x': [0, 1], 'y': [0, 1]}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="cVSrMi"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..ymin..":[],
# "..ymax..":[],
# "x":[],
# "y":[]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cVSrMi");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot({'x': [0, 1, 2], 'y': [0, 1, 4]}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="aHT8O1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# ...

# %%
ggplot({'x': [0, 1, 2, 3], 'y': [0, 1, 4, np.nan]}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="hWsxmF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# ...

# %%
ggplot({'x': [0, 1, 2], 'y': [0, 1, np.nan]}, aes('x', 'y')) + geom_smooth()
# Out:
#    <div id="KL1y9n"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "__error_message":"Internal error: IllegalStateException : NotStrictlyPositive - DEGREES_OF_FREEDOM: 0.0"
# };
#            var plotContainer = document.getElementById("KL1y9n");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
