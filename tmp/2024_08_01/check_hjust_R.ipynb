# %%
library(ggplot2)

# %%
ggplot() +
    geom_segment(aes(x = 0, y = 0, xend = 1, yend = 0, linewidth = 1, color = 'red')) +
    geom_label(aes(x = 0, y = 0, hjust = 0, label = "a", size = 1), label.size = 0) +
    theme_void()
# Out:
# plot without title
