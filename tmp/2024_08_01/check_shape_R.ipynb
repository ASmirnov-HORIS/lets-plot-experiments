# %%
library(ggplot2)

# %%
ggplot() + geom_point(aes(x = c(0, 1), y = c(0, 0), shape = c(16, 19)), size = 10, stroke = 30, color = "red", fill = "green") + scale_shape_identity()
# Out:
# plot without title
