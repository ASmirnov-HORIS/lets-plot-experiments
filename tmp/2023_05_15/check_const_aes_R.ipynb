# %%
library(ggplot2)

# %%
df <- data.frame(
    x = c(0, 0, 0),
    g = c('a', 'a', 'b')
)

# %%
ggplot(df) +
    geom_bar(aes(x = x, fill = g))
# Out:
# plot without title

# %% [markdown]
# Так как x == 0, по идее, ту же картинку должен дать следующий код:

# %%
ggplot(df) +
    geom_bar(aes(x = 0, fill = g))
# Out:
# plot without title
