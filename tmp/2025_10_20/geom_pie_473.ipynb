# %% [markdown]
# # Check Pie Grouping

# %%
import geopandas as gpd
import shapely as sh

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="AdMwD9"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("AdMwD9").appendChild(div);
#                     };
#                     var e = document.getElementById("AdMwD9");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data1 = {
    "City_Code": [ "A", "A", "B", "B" ], 
    "City_Name": [ "City A", "City A", "City B", "City B" ],
    "Vote": [ "Yes", "No", "Yes", "No" ], 
    "Number": [ 120.0, 30.0, 20.0, 80.0 ], 
}
cities = gpd.GeoDataFrame({
    "id": [ "A", "B" ],
    "geometry": [
        sh.geometry.Point(-80.0, -40.0),
        sh.geometry.Point(80.0, 40.0)
    ]
}, crs="EPSG:4326")

# %%
def plot(data):
    return ggplot(data) + \
        scale_x_continuous(expand=[0.3]) + \
        scale_y_continuous(expand=[0.3])

points = geom_point(map=cities, map_join=["City_Code", "id"], shape=21, fill="yellow")

# %% [markdown]
# ## With `map_join`

# %%
params = {"map": cities, "map_join": ["City_Code", "id"]}

gggrid([
    plot(data1) + geom_pie(
            aes(fill="Vote", weight="Number",
                group="City_Code"), 
            **params
        ) + \
    points + ggtitle('group="City_Code"'),
    #plot(data1) + geom_pie(
    #        aes(fill="Vote", weight="Number",
    #            group=["City_Code", "Vote"]), 
    #        **params
    #    ) + \
    #points + ggtitle('group=["City_Code", "Vote"]'),
    plot(data1) + geom_pie(
            aes(fill="Vote", slice="Number"),
            stat='identity', 
            **params
        ) + \
    points + ggtitle("Without group, stat='identity'"),
    plot(data1) + geom_pie(
            aes(fill="Vote", weight="Number"), 
            **params
        ) + \
    points + ggtitle("Without group"),
    plot(data1) + geom_pie(**params) + \
    points + ggtitle("Without any mapping"),
], ncol=2)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="c7FpBs"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("c7FpBs");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# }]
# },
# "ggtitle":{
# "text":"group=\"City_Code\""
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "fill":"Vote",
# "weight":"Number",
# "group":"City_Code"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0,0.0,0.0,0.0],
# "..y..":[0.0,0.0,0.0,0.0],
# "..count..":[120.0,30.0,20.0,80.0],
# "Vote":["Yes","No","Yes","No"],
# "City_Code":["A","A","B","B"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "data":{
# "City_Code":["A","A","B","B"],
# "Vote":["Yes","No","Yes","No"],
# "Number":[120.0,30.0,20.0,80.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# }]
# },
# "ggtitle":{
# "text":"Without group, stat='identity'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Vote",
# "slice":"Number"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# }]
# },
# "ggtitle":{
# "text":"Without group"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "fill":"Vote",
# "weight":"Number"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0,0.0],
# "..y..":[0.0,0.0],
# "..count..":[140.0,110.0],
# "Vote":["Yes","No"],
# "City_Code":["A","A"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# }]
# },
# "ggtitle":{
# "text":"Without any mapping"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0],
# "..y..":[0.0],
# "..count..":[4.0],
# "City_Code":["A"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-29460dd47b0c435fbeeecbc2618c4173', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-29460dd47b0c435fbeeecbc2618c4173" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipbo

# %% [markdown]
# ## Without `map_join`

# %%
data2 = {
    "City_Code": [ "A", "A", "B", "B" ], 
    "City_Name": [ "City A", "City A", "City B", "City B" ],
    "Vote": [ "Yes", "No", "Yes", "No" ], 
    "Number": [ 120.0, 30.0, 20.0, 80.0 ], 
    "x": [-80.0, -80.0, 80.0, 80.0],
    "y": [-40.0, -40.0, 40.0, 40.0]
}

# %%
gggrid([
    plot(data2) + geom_pie(
        aes("x", "y", fill="Vote", weight="Number",
            group="City_Code")
    ) + points + ggtitle('group="City_Code"'),
    #plot(data2) + geom_pie(
    #    aes("x", "y", fill="Vote", weight="Number",
    #        group=["City_Code", "Vote"])
    #) + points + ggtitle('group=["City_Code", "Vote"]'),
    plot(data2) + geom_pie(
        aes("x", "y", fill="Vote", slice="Number"),
        stat='identity'
    ) + points + ggtitle("Without group, stat='identity'"),
    plot(data2) + geom_pie(
        aes("x", "y", fill="Vote", weight="Number")
    ) + points + ggtitle("Without group"),
    plot(data2) + geom_pie(
        aes("x", "y")
    ) + points + ggtitle("Without any mapping"),
], ncol=2)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="lfw9lY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("lfw9lY");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"group=\"City_Code\""
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "weight":"Number",
# "group":"City_Code"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[120.0,30.0,20.0,80.0],
# "x":[-80.0,-80.0,80.0,80.0],
# "y":[-40.0,-40.0,40.0,40.0],
# "Vote":["Yes","No","Yes","No"],
# "City_Code":["A","A","B","B"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# "City_Code":["A","A","B","B"],
# "Vote":["Yes","No","Yes","No"],
# "Number":[120.0,30.0,20.0,80.0],
# "x":[-80.0,-80.0,80.0,80.0],
# "y":[-40.0,-40.0,40.0,40.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"Without group, stat='identity'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "slice":"Number"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"Without group"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "weight":"Number"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[120.0,20.0,30.0,80.0],
# "x":[-80.0,80.0,-80.0,80.0],
# "y":[-40.0,40.0,-40.0,40.0],
# "Vote":["Yes","Yes","No","No"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"City_Code"
# },{
# "type":"str",
# "column":"City_Name"
# },{
# "type":"str",
# "column":"Vote"
# },{
# "type":"float",
# "column":"Number"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"Without any mapping"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[2.0,2.0],
# "x":[-80.0,80.0],
# "y":[-40.0,40.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21.0,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-ec40b147da2c402d97fb715b70a737c6', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-ec40b147da2c402d97fb715b70a737c6" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
