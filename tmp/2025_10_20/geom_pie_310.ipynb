# %% [markdown]
# # Check Pie Grouping

# %%
import geopandas as gpd
import shapely as sh

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="9IzzMk"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.1.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("9IzzMk").appendChild(div);
#                     };
#                     var e = document.getElementById("9IzzMk");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data1 = {
    "City_Code": [ "A", "A", "B", "B" ], 
    "City_Name": [ "City A", "City A", "City B", "City B" ],
    "Vote": [ "Yes", "No", "Yes", "No" ], 
    "Number": [ 120.0, 30.0, 20.0, 80.0 ], 
}
cities = gpd.GeoDataFrame({
    "id": [ "A", "B" ],
    "geometry": [
        sh.geometry.Point(-80.0, -40.0),
        sh.geometry.Point(80.0, 40.0)
    ]
}, crs="EPSG:4326")

# %%
def plot(data):
    return ggplot(data) + \
        scale_x_continuous(expand=[0.3]) + \
        scale_y_continuous(expand=[0.3])

points = geom_point(map=cities, map_join=["City_Code", "id"], shape=21, fill="yellow")

# %% [markdown]
# ## With `map_join`

# %%
params = {"map": cities, "map_join": ["City_Code", "id"]}

w, h = 400, 300
bunch = GGBunch()
bunch.add_plot(plot(data1) + geom_pie(
    aes(fill="Vote", weight="Number",
        group="City_Code"), 
    **params) + \
    points + ggtitle('group="City_Code"'),
0, 0, w, h)
bunch.add_plot(plot(data1) + geom_pie(
    aes(fill="Vote", slice="Number"),
    stat='identity', 
    **params) + \
    points + ggtitle("Without group, stat='identity'"),
w, 0, w, h)
bunch.add_plot(plot(data1) + geom_pie(
    aes(fill="Vote", weight="Number"), 
    **params) + \
    points + ggtitle("Without group"),
0, h, w, h)
bunch.add_plot(plot(data1) + geom_pie(**params) + \
    points + ggtitle("Without any mapping"),
w, h, w, h)
bunch.show()
# Out:
#    <div id="36hFXt"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"group=\"City_Code\""
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "fill":"Vote",
# "weight":"Number",
# "group":"City_Code"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0,0.0,0.0,0.0],
# "..y..":[0.0,0.0,0.0,0.0],
# "..count..":[120.0,30.0,20.0,80.0],
# "Vote":["Yes","No","Yes","No"],
# "City_Code":["A","A","B","B"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"],
# "Vote":["Yes","No","Yes","No"],
# "Number":[120.0,30.0,20.0,80.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without group, stat='identity'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Vote",
# "slice":"Number"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without group"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "fill":"Vote",
# "weight":"Number"
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0,0.0],
# "..y..":[0.0,0.0],
# "..count..":[140.0,110.0],
# "Vote":["Yes","No"],
# "City_Code":["A","A"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without any mapping"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# "..x..":[0.0],
# "..y..":[0.0],
# "..count..":[4.0],
# "City_Code":["A"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("36hFXt");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Without `map_join`

# %%
data2 = {
    "City_Code": [ "A", "A", "B", "B" ], 
    "City_Name": [ "City A", "City A", "City B", "City B" ],
    "Vote": [ "Yes", "No", "Yes", "No" ], 
    "Number": [ 120.0, 30.0, 20.0, 80.0 ], 
    "x": [-80.0, -80.0, 80.0, 80.0],
    "y": [-40.0, -40.0, 40.0, 40.0]
}

# %%
w, h = 400, 300
bunch = GGBunch()
bunch.add_plot(plot(data2) + geom_pie(
    aes("x", "y", fill="Vote", weight="Number",
        group="City_Code")
    ) + points + ggtitle('group="City_Code"'),
0, 0, w, h)
bunch.add_plot(plot(data2) + geom_pie(
    aes("x", "y", fill="Vote", slice="Number"),
    stat='identity'
    ) + points + ggtitle("Without group, stat='identity'"),
w, 0, w, h)
bunch.add_plot(plot(data2) + geom_pie(
    aes("x", "y", fill="Vote", weight="Number")
    ) + points + ggtitle("Without group"),
0, h, w, h)
bunch.add_plot(plot(data2) + geom_pie(
    aes("x", "y")
    ) + points + ggtitle("Without any mapping"),
w, h, w, h)
bunch.show()
# Out:
#    <div id="q69KXR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"group=\"City_Code\""
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "weight":"Number",
# "group":"City_Code"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[120.0,30.0,20.0,80.0],
# "x":[-80.0,-80.0,80.0,80.0],
# "y":[-40.0,-40.0,40.0,40.0],
# "Vote":["Yes","No","Yes","No"],
# "City_Code":["A","A","B","B"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"],
# "Vote":["Yes","No","Yes","No"],
# "Number":[120.0,30.0,20.0,80.0],
# "x":[-80.0,-80.0,80.0,80.0],
# "y":[-40.0,-40.0,40.0,40.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without group, stat='identity'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "slice":"Number"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without group"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y",
# "fill":"Vote",
# "weight":"Number"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[120.0,20.0,30.0,80.0],
# "x":[-80.0,80.0,-80.0,80.0],
# "y":[-40.0,40.0,-40.0,40.0],
# "Vote":["Yes","Yes","No","No"]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400,
# "y":300,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# "City_Code":["A","A","B","B"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Without any mapping"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0.3]
# },{
# "aesthetic":"y",
# "expand":[0.3]
# }],
# "layers":[{
# "geom":"pie",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[2.0,2.0],
# "x":[-80.0,80.0],
# "y":[-40.0,40.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "id":["A","B"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-80.0, -40.0]}","{\"type\": \"Point\", \"coordinates\": [80.0, 40.0]}"]
# },
# "map_join":[["City_Code"],["id"]],
# "shape":21,
# "fill":"yellow",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("q69KXR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
