# %%
library(ggplot2)

# %%
df <- data.frame(x = c(0, 0), y = c(1, 2), r = c(1, 2))

# %%
p <- ggplot(df, aes(x, y)) + geom_spoke(aes(radius = r), angle = 0)
p
# Out:
# plot without title

# %%
p + xlim(-4, 4)
# Out:
# plot without title
