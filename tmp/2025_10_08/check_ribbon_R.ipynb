# %%
library(ggplot2)

# %%
df <- data.frame(
    x = c(1, 2, 3, 4, 5),
    ymin = c(-1, -3, NA, -5, -4),
    ymax = c(1, 3, 2, 5, 4)
)

# %% [markdown]
# ## Current behaviour

# %%
ggplot(df) + geom_ribbon(aes(x = x, ymin = ymin, ymax = ymax))
# Out:
# plot without title
