# %%
library(ggplot2)

# %%
df <- data.frame(
    decade = c(0.01, 0.09, 0.09)
)

# %% [markdown]
# ## Default

# %%
ggplot(df) +
    geom_bar(aes(x = decade))
# Out:
# plot without title

# %%
ggplot(df) +
    geom_bar(aes(x = as.factor(decade)))
# Out:
# plot without title

# %% [markdown]
# ## With `scale_x_discrete()`

# %%
ggplot(df) +
    geom_bar(aes(x = decade)) +
    scale_x_discrete(name = "Decade")
# Out:
# Warning message:
# “`position_stack()` requires non-overlapping x intervals.”
# plot without title

# %% [markdown]
# ## With `scale_x_discrete()` and `as.factor()`

# %%
ggplot(df) +
    geom_bar(aes(x = as.factor(decade))) +
    scale_x_discrete(name = "Decade")
# Out:
# plot without title
