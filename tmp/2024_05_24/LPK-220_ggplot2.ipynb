# %%
library(ggplot2)

# %%
df <- data.frame(x = c("A", "B", "C", "D"))

# %%
ggplot(df) +
    geom_boxplot(aes(x = x, lower = 25, middle = 50, upper = 75, ymin = 0, ymax = 100),
                 stat = 'identity', linetype = 'dotted', size = 2.5)
# Out:
# plot without title

# %%
ggplot(df) +
    geom_boxplot(aes(x = x, lower = 25, middle = 50, upper = 75, ymin = 0, ymax = 100),
                 stat = 'identity', linetype = 'dotted', size = 5)
# Out:
# plot without title

# %%
ggplot(df) +
    geom_crossbar(aes(x = x, y = 50, ymin = 25, ymax = 75),
                  linetype = 'dotted', linewidth = 2.5)
# Out:
# plot without title
