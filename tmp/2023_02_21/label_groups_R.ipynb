# %%
library(ggplot2)

# %%
df <- data.frame(
    x = c(0, 1, 2, 3),
    y = c(1, 1, 1, 1),
    l = c("a", "b", "c", "d")
)

# %%
ggplot(df, aes(x, y)) +
    geom_label(aes(label = l, color = after_stat(group)), size = 10)
# Out:
# plot without title
