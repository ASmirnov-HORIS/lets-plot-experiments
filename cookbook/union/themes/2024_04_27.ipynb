# %% [markdown]
# # Lets-Plot Themes

# %%
import numpy as np
import pandas as pd
from PIL import Image

from lets_plot import *
from lets_plot.geo_data import *
from lets_plot.bistro.corr import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="BgtDwY"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("BgtDwY").appendChild(div);
#                     };
#                     var e = document.getElementById("BgtDwY");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
print(df.shape)
df.head()
# Out:
# (234, 12)
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
# 4           5         audi    a4    2.8  1999    6    auto(l5)   f   16   26
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact
# 4  p  compact

# %%
def bar_title(subtitle):
    return ggtitle("Bar plot", subtitle)

def bar_plot(*, color=True, facet=False, sampling=None):
    color_col = "fl" if color else None
    plot = ggplot(df) + \
        geom_bar(aes("fl", color=color_col, fill=color_col), \
                 sampling=sampling, \
                 tooltips=layer_tooltips().title("Fuel type: @fl").line("count|@..count.."))
    if facet:
        plot += facet_grid(x="year")
    return plot

# %% [markdown]
# ## 1. Custom Theme

# %%
def orange_theme():
    yellow_light = "#ffffcc"
    orange_light = "#fff5eb"
    orange_normal = "#f16913"
    orange_dark = "#7f2704"
    return theme_none() + theme(
        line=element_line(color=orange_normal, size=2),
        rect=element_rect(color=orange_normal, fill=orange_light, size=2),
        text=element_text(color=orange_dark),
        axis_ontop=True,
        axis_ticks=element_line(color=orange_normal, size=2),
        axis_ticks_length=7,
        legend_background=element_rect(size=2, fill=orange_light),
        legend_position='bottom',
        panel_grid_major=element_line(color=orange_normal, size=.5),
        panel_grid_minor='blank',
        plot_background=element_rect(fill=yellow_light, size=2),
        plot_title=element_text(size=20, face='bold'),
        axis_tooltip=element_rect(color=orange_dark)
    )

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + orange_theme() + bar_title("Custom theme"),
])
# Out:
#    <div id="ggZxG1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"none",
# "line":{
# "color":"#f16913",
# "size":2.0,
# "blank":false
# },
# "rect":{
# "fill":"#fff5eb",
# "color":"#f16913",
# "size":2.0,
# "blank":false
# },
# "text":{
# "color":"#7f2704",
# "blank":false
# },
# "axis_ontop":true,
# "axis_ticks":{
# "color":"#f16913",
# "size":2.0,
# "blank":false
# },
# "axis_ticks_length":7.0,
# "legend_background":{
# "fill":"#fff5eb",
# "size":2.0,
# "blank":false
# },
# "legend_position":"bottom",
# "panel_grid_major":{
# "color":"#f16913",
# "size":0.5,
# "blank":false
# },
# "panel_grid_minor":"blank",
# "plot_background":{
# "fill":"#ffffcc",
# "size":2.0,
# "blank":false
# },
# "plot_title":{
# "face":"bold",
# "size":20.0,
# "blank":false
# },
# "axis_tooltip":{
# "color":"#7f2704",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom theme"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ggZxG1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## 2. Theme Elements

# %% [markdown]
# ### 2.1. Lines

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(panel_grid=element_line(color="red", size=2, linetype='longdash')) + \
        bar_title("Custom element_line() for panel grid"),
])
# Out:
#    <div id="uTLgND"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid":{
# "color":"red",
# "size":2.0,
# "linetype":"longdash",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom element_line() for panel grid"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("uTLgND");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 2.2. Rectangles

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(panel_background=element_rect(color="black", fill="lightgray", size=2, linetype='longdash')) + \
        bar_title("Custom element_rect() for panel background"),
])
# Out:
#    <div id="WElSlA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"lightgray",
# "color":"black",
# "size":2.0,
# "linetype":"longdash",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom element_rect() for panel background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("WElSlA");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 2.3. Texts

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_text_y=element_text(color="red", family="Times", \
                                       face='bold', size=20, angle=15, \
                                       margin=[0, 5])) + \
        bar_title("Custom element_text() for y-axis text"),
])
# Out:
#    <div id="cnw8IB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_text_y":{
# "color":"red",
# "family":"Times",
# "face":"bold",
# "size":20.0,
# "angle":15.0,
# "margin":[0.0,5.0],
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom element_text() for y-axis text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("cnw8IB");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 2.4. Geometries

# %%
gggrid([
    bar_plot(color=False) + bar_title("Default"),
    bar_plot(color=False) + \
        theme(geom=element_geom(brush="yellow", paper="red")) + \
        bar_title("Custom element_geom() for geom"),
])
# Out:
#    <div id="HIbaXI"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "geom":{
# "brush":"yellow",
# "paper":"red"
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom element_geom() for geom"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("HIbaXI");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 2.5. Blank

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(panel_grid=element_blank()) + \
        bar_title("panel_grid=element_blank()"),
    bar_plot() + \
        theme(panel_grid='blank') + \
        bar_title("panel_grid='blank'"),
    bar_plot() + \
        theme(panel_grid=element_line(blank=True)) + \
        bar_title("panel_grid=element_line(blank=True)"),
], ncol=2)
# Out:
#    <div id="Mt049L"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid":{
# "blank":true
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_grid=element_blank()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid":"blank"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_grid='blank'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid":{
# "blank":true
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_grid=element_line(blank=True)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("Mt049L");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## 3. Theme Parameters

# %% [markdown]
# ### 3.1. All Elements of Given Type

# %% [markdown]
# #### `line`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(line=element_line(linetype='longdash')) + \
        bar_title("Custom line"),
])
# Out:
#    <div id="9KgFcx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "line":{
# "linetype":"longdash",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom line"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("9KgFcx");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `rect`

# %%
# The default theme has defaults for most rectangular elements,
# so we need to switch to another predefined theme to see the effect

gggrid([
    bar_plot() + theme_light() + bar_title("Default"),
    bar_plot() + theme_light() + \
        theme(rect=element_rect(linetype='longdash')) + \
        bar_title("Custom rect"),
])
# Out:
#    <div id="afiLGL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"light"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"light",
# "rect":{
# "linetype":"longdash",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom rect"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("afiLGL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `text` and `title`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(text=element_text(color="red")) + \
        bar_title("Custom text"),
    bar_plot() + \
        theme(title=element_text(color="blue")) + \
        bar_title("Custom title"),
    bar_plot() + \
        theme(text=element_text(color="red"), title=element_text(color="blue")) + \
        bar_title("Custom text and title"),
], ncol=2)
# Out:
#    <div id="AH39qu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "text":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "title":{
# "color":"blue",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom title"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "text":{
# "color":"red",
# "blank":false
# },
# "title":{
# "color":"blue",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom text and title"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("AH39qu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.2. Axes

# %% [markdown]
# #### `axis`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis=element_line(color="red", size=3)) + \
        bar_title("Custom axis"),
])
# Out:
#    <div id="sbly9L"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis":{
# "color":"red",
# "size":3.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("sbly9L");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_ontop`

# %%
gggrid([
    bar_plot() + \
        theme(axis=element_text(size=4)) + \
        bar_title("axis_ontop=True (default)"),
    bar_plot() + \
        theme(axis=element_text(size=4), axis_ontop=False) + \
        bar_title("axis_ontop=False"),
])
# Out:
#    <div id="2gkCCk"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis":{
# "size":4.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"axis_ontop=True (default)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis":{
# "size":4.0,
# "blank":false
# },
# "axis_ontop":false
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"axis_ontop=False"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("2gkCCk");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_title`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_title=element_text(color="red")) + \
        bar_title("Custom axis_title"),
])
# Out:
#    <div id="ptJPKT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_title"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ptJPKT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_text`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_text=element_text(color="red")) + \
        bar_title("Custom axis_text"),
])
# Out:
#    <div id="ZkTdkU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_text":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ZkTdkU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_ticks` and `axis_ticks_length`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_ticks=element_line(color="red", size=3)) + \
        bar_title("Custom axis_ticks"),
    bar_plot() + \
        theme(axis_ticks_length=10) + \
        bar_title("Custom axis_ticks_length"),
])
# Out:
#    <div id="wvMMVu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_ticks":{
# "color":"red",
# "size":3.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_ticks"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_ticks_length":10.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_ticks_length"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("wvMMVu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_line`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_line=element_line(color="red", size=3)) + \
        bar_title("Custom axis_line"),
])
# Out:
#    <div id="dR880P"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_line":{
# "color":"red",
# "size":3.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_line"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("dR880P");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.3. Legend

# %% [markdown]
# #### `legend_background`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(legend_background=element_rect(fill="lightgray")) + \
        bar_title("Custom legend_background"),
])
# Out:
#    <div id="gTwixk"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_background":{
# "fill":"lightgray",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom legend_background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("gTwixk");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `legend_text`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(legend_text=element_text(color="red")) + \
        bar_title("Custom legend_text"),
])
# Out:
#    <div id="cXN7Cl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_text":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom legend_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("cXN7Cl");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `legend_title`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(legend_title=element_text(color="red")) + \
        bar_title("Custom legend_title"),
])
# Out:
#    <div id="nibXxc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_title":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom legend_title"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("nibXxc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `legend_position` and `legend_justification`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(legend_position='top') + \
        bar_title("legend_position='top'"),
    bar_plot() + \
        theme(legend_position=[1, 1]) + \
        bar_title("legend_position=[1, 1]"),
    bar_plot() + \
        theme(legend_position=[1, 1], legend_justification=[1, .7]) + \
        bar_title("legend_position=[1, 1], legend_justification=[1, .7]"),
], ncol=2)
# Out:
#    <div id="AmIdKc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"top"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"legend_position='top'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":[1.0,1.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"legend_position=[1, 1]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":[1.0,1.0],
# "legend_justification":[1.0,0.7]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"legend_position=[1, 1], legend_justification=[1, .7]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("AmIdKc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `legend_direction`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(legend_direction='horizontal') + \
        bar_title("Custom legend_direction"),
])
# Out:
#    <div id="2w85Gg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_direction":"horizontal"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom legend_direction"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("2w85Gg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.4. Panel

# %% [markdown]
# #### `panel_background` and `panel_border`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(panel_background=element_rect(color="black", fill="lightgray")) + \
        bar_title("Custom panel_background"),
    bar_plot() + \
        theme(panel_border=element_rect(size=3, color="red")) + \
        bar_title("Custom panel_border"),
    bar_plot() + \
        theme(panel_background=element_rect(color="black", fill="lightgray"), \
              panel_border=element_rect(size=3, color="red")) + \
        bar_title("Custom panel_background and panel_border"),
], ncol=2)
# Out:
#    <div id="Rfl4H0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"lightgray",
# "color":"black",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom panel_background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_border":{
# "color":"red",
# "size":3.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom panel_border"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"lightgray",
# "color":"black",
# "blank":false
# },
# "panel_border":{
# "color":"red",
# "size":3.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom panel_background and panel_border"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("Rfl4H0");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `panel_grid`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(panel_grid=element_line(linetype='longdash')) + \
        bar_title("Custom panel_grid"),
])
# Out:
#    <div id="8aBPZ0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid":{
# "linetype":"longdash",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom panel_grid"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("8aBPZ0");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `panel_border_ontop`

# %%
gggrid([
    bar_plot() + \
        theme(panel_border=element_rect(size=5)) + \
        bar_title("panel_border_ontop=True (default)"),
    bar_plot() + \
        theme(panel_border=element_rect(size=5), panel_border_ontop=False) + \
        bar_title("panel_border_ontop=False"),
])
# Out:
#    <div id="hRsDks"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_border":{
# "size":5.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_border_ontop=True (default)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_border":{
# "size":5.0,
# "blank":false
# },
# "panel_border_ontop":false
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_border_ontop=False"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("hRsDks");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `panel_grid_ontop`

# %%
gggrid([
    bar_plot() + \
        bar_title("panel_grid_ontop=False (default)"),
    bar_plot() + \
        theme(panel_grid_ontop=True) + \
        bar_title("panel_grid_ontop=True"),
])
# Out:
#    <div id="GGFeNe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_grid_ontop=False (default)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_grid_ontop":true
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_grid_ontop=True"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("GGFeNe");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `panel_inset`

# %%
# Add a custom theme to better see what happens when the panel_inset is specified

gggrid([
    bar_plot() + theme_grey() + bar_title("Default"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=50) + \
        bar_title("panel_inset=50"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=[50]) + \
        bar_title("panel_inset=[50]"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=[50, 25]) + \
        bar_title("panel_inset=[50, 25]"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=[100, 25, 50]) + \
        bar_title("panel_inset=[100, 25, 50]"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=[100, 0, 50, 25]) + \
        bar_title("panel_inset=[100, 0, 50, 25]"),
], ncol=3)
# Out:
#    <div id="DmFFYj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":[50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=[50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":[50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=[50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":[100.0,25.0,50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=[100, 25, 50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":[100.0,0.0,50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=[100, 0, 50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("DmFFYj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.5. Plot

# %% [markdown]
# #### `plot_background`

# %%
gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(plot_background=element_rect(fill="lightgray")) + \
        bar_title("Custom plot_background"),
    bar_plot() + \
        theme(plot_background=element_rect(fill="lightgray"), \
              panel_background=element_rect(fill="white")) + \
        bar_title("plot_background vs. panel_background"),
])
# Out:
#    <div id="uYVz4H"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_background":{
# "fill":"lightgray",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom plot_background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"white",
# "blank":false
# },
# "plot_background":{
# "fill":"lightgray",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_background vs. panel_background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("uYVz4H");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `plot_title`, `plot_subtitle`, `plot_caption`

# %%
gggrid([
    bar_plot() + \
        labs(title="Default title", subtitle="Default subtitle", caption="Default caption"),
    bar_plot() + \
        theme(plot_title=element_text(color="red")) + \
        labs(title="Custom plot_title", subtitle="Default subtitle", caption="Default caption"),
    bar_plot() + \
        theme(plot_subtitle=element_text(color="red")) + \
        labs(title="Default title", subtitle="Custom plot_subtitle", caption="Default caption"),
    bar_plot() + \
        theme(plot_caption=element_text(color="red")) + \
        labs(title="Default title", subtitle="Default subtitle", caption="Custom plot_caption"),
], ncol=2)
# Out:
#    <div id="r9Z58U"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default title",
# "subtitle":"Default subtitle"
# },
# "caption":{
# "text":"Default caption"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_title":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Custom plot_title",
# "subtitle":"Default subtitle"
# },
# "caption":{
# "text":"Default caption"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_subtitle":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Default title",
# "subtitle":"Custom plot_subtitle"
# },
# "caption":{
# "text":"Default caption"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_caption":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Default title",
# "subtitle":"Default subtitle"
# },
# "caption":{
# "text":"Custom plot_caption"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("r9Z58U");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `plot_margin`

# %%
# Add a custom theme to better see what happens when the plot_margin is specified

gggrid([
    bar_plot() + theme_grey() + bar_title("Default"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=50) + \
        bar_title("plot_margin=50"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=[50]) + \
        bar_title("plot_margin=[50]"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=[50, 25]) + \
        bar_title("plot_margin=[50, 25]"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=[100, 25, 50]) + \
        bar_title("plot_margin=[100, 25, 50]"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=[100, 0, 50, 25]) + \
        bar_title("plot_margin=[100, 0, 50, 25]"),
], ncol=3)
# Out:
#    <div id="49YkSj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":[50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=[50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":[50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=[50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":[100.0,25.0,50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=[100, 25, 50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":[100.0,0.0,50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=[100, 0, 50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("49YkSj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `plot_inset`

# %%
# Add a custom theme to better see what happens when the plot_inset is specified

gggrid([
    bar_plot() + theme_grey() + bar_title("Default"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=50) + \
        bar_title("plot_inset=50"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=[50]) + \
        bar_title("plot_inset=[50]"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=[50, 25]) + \
        bar_title("plot_inset=[50, 25]"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=[100, 25, 50]) + \
        bar_title("plot_inset=[100, 25, 50]"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=[100, 0, 50, 25]) + \
        bar_title("plot_inset=[100, 0, 50, 25]"),
], ncol=3)
# Out:
#    <div id="c3e19r"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":[50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=[50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":[50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=[50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":[100.0,25.0,50.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=[100, 25, 50]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":[100.0,0.0,50.0,25.0]
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=[100, 0, 50, 25]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("c3e19r");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `plot_margin` vs. `plot_inset` vs. `panel_inset`

# %%
# Add a custom theme to better see what happens when the parameters are specified

gggrid([
    bar_plot() + theme_grey() + bar_title("Default"),
    bar_plot() + theme_grey() + \
        theme(plot_margin=50) + \
        bar_title("plot_margin=50"),
    bar_plot() + theme_grey() + \
        theme(plot_inset=50) + \
        bar_title("plot_inset=50"),
    bar_plot() + theme_grey() + \
        theme(panel_inset=50) + \
        bar_title("panel_inset=50"),
], ncol=2)
# Out:
#    <div id="QyegUg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_margin":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_margin=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "plot_inset":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_inset=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "panel_inset":50.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"panel_inset=50"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("QyegUg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `plot_message`

# %%
gggrid([
    bar_plot(sampling=sampling_pick(3)) + bar_title("Default"),
    bar_plot(sampling=sampling_pick(3)) + \
        theme(plot_message='blank') + \
        bar_title("plot_message='blank'"),
])
# Out:
#    <div id="fV2CyT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "sampling":{
# "name":"pick",
# "n":3.0
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0],
# "fl":["p","r","e"]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_pick(n=3) was applied to [bar/count stat] layer"]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"plot_message='blank'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "sampling":{
# "name":"pick",
# "n":3.0
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0],
# "fl":["p","r","e"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("fV2CyT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.6. Facetting

# %% [markdown]
# #### `strip_background`

# %%
gggrid([
    bar_plot(facet=True) + bar_title("Default"),
    bar_plot(facet=True) + \
        theme(strip_background=element_rect()) + \
        bar_title("Custom strip_background"),
])
# Out:
#    <div id="uPe4iO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"year",
# "x_order":1.0,
# "y_order":1.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"fl",
# "factor_levels":["p","r","e","d","c"]
# }]
# },
# "data":{
# "..count..":[20.0,93.0,4.0,32.0,75.0,8.0,1.0,1.0],
# "fl":["p","r","d","p","r","e","d","c"],
# "year":[1999.0,1999.0,1999.0,2008.0,2008.0,2008.0,2008.0,2008.0]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"year",
# "x_order":1.0,
# "y_order":1.0
# },
# "theme":{
# "strip_background":{
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom strip_background"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"fl",
# "factor_levels":["p","r","e","d","c"]
# }]
# },
# "data":{
# "..count..":[20.0,93.0,4.0,32.0,75.0,8.0,1.0,1.0],
# "fl":["p","r","d","p","r","e","d","c"],
# "year":[1999.0,1999.0,1999.0,2008.0,2008.0,2008.0,2008.0,2008.0]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("uPe4iO");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `strip_text`

# %%
gggrid([
    bar_plot(facet=True) + bar_title("Default"),
    bar_plot(facet=True) + \
        theme(strip_text=element_text(color="red")) + \
        bar_title("Custom strip_text"),
])
# Out:
#    <div id="CfrET1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"year",
# "x_order":1.0,
# "y_order":1.0
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"fl",
# "factor_levels":["p","r","e","d","c"]
# }]
# },
# "data":{
# "..count..":[20.0,93.0,4.0,32.0,75.0,8.0,1.0,1.0],
# "fl":["p","r","d","p","r","e","d","c"],
# "year":[1999.0,1999.0,1999.0,2008.0,2008.0,2008.0,2008.0,2008.0]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"year",
# "x_order":1.0,
# "y_order":1.0
# },
# "theme":{
# "strip_text":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom strip_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"fl",
# "factor_levels":["p","r","e","d","c"]
# }]
# },
# "data":{
# "..count..":[20.0,93.0,4.0,32.0,75.0,8.0,1.0,1.0],
# "fl":["p","r","d","p","r","e","d","c"],
# "year":[1999.0,1999.0,1999.0,2008.0,2008.0,2008.0,2008.0,2008.0]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("CfrET1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.7. Tooltips

# %% [markdown]
# #### `tooltip`

# %%
# Hover over the plot to see tooltips

gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(tooltip=element_rect(color="red", fill="yellow")) + \
        bar_title("Custom tooltip"),
])
# Out:
#    <div id="3aM38Y"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "tooltip":{
# "fill":"yellow",
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom tooltip"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("3aM38Y");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `tooltip_text` and `tooltip_title_text`

# %%
# Hover over the plot to see tooltips

gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(tooltip_text=element_text(color="red")) + \
        bar_title("Custom tooltip_text"),
    bar_plot() + \
        theme(tooltip_title_text=element_text(color="blue")) + \
        bar_title("Custom tooltip_title_text"),
    bar_plot() + \
        theme(tooltip_text=element_text(color="red"), \
              tooltip_title_text=element_text(color="blue")) + \
        bar_title("Custom tooltip_text and tooltip_title_text"),
], ncol=2)
# Out:
#    <div id="RKnq1J"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "tooltip_text":{
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom tooltip_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "tooltip_title_text":{
# "color":"blue",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom tooltip_title_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "tooltip_text":{
# "color":"red",
# "blank":false
# },
# "tooltip_title_text":{
# "color":"blue",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom tooltip_text and tooltip_title_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("RKnq1J");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `axis_tooltip` and `axis_tooltip_text`

# %%
# Hover over the plot to see tooltips

gggrid([
    bar_plot() + bar_title("Default"),
    bar_plot() + \
        theme(axis_tooltip=element_rect(color="red", fill="blue")) + \
        bar_title("Custom axis_tooltip"),
    bar_plot() + \
        theme(axis_tooltip_text=element_text(color="yellow")) + \
        bar_title("Custom axis_tooltip_text"),
    bar_plot() + \
        theme(axis_tooltip=element_rect(color="red", fill="blue"), \
              axis_tooltip_text=element_text(color="yellow")) + \
        bar_title("Custom axis_tooltip and axis_tooltip_text"),
], ncol=2)
# Out:
#    <div id="5FaRcs"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_tooltip":{
# "fill":"blue",
# "color":"red",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_tooltip"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_tooltip_text":{
# "color":"yellow",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_tooltip_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_tooltip":{
# "fill":"blue",
# "color":"red",
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"yellow",
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar plot",
# "subtitle":"Custom axis_tooltip and axis_tooltip_text"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"fl",
# "color":"fl",
# "fill":"fl"
# },
# "tooltips":{
# "formats":[],
# "lines":["count|@..count.."],
# "title":"Fuel type: @fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("5FaRcs");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### 3.8. Labels

# %%
# TODO

# %% [markdown]
# ### 3.9. Other

# %%
# TODO

# %% [markdown]
# #### `exponent_format`

# %% [markdown]
# ## 4. Extra

# %% [markdown]
# ### 4.1. Plot Size

# %%
# TODO

# %% [markdown]
# ### 4.2. Title, Subtitle, Caption

# %%
# TODO

# %% [markdown]
# ## 5. Set up Global Theme

# %%
# TODO
